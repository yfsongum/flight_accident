# %% [markdown]
# # Project Title: Flight Accidents Analysis

# %% [markdown]
# ## [TODO] Team Members with uniqname
# * Yufeng Song (yfsong)
# * Ziqi Wang ()
# * Muyu Lin (mlin567)

# %% [markdown]
# ## Overview
# Our project analyzes historical flight accident data to determine trends in aviation safety and identify key factors contributing to accidents. We aim to assess whether the perceived increase in plane accidents this year is due to actual incidents or amplified media coverage. By uncovering patterns, we can help improve aviation safety and inform future risk mitigation strategies.

# %% [markdown]
# ## Motivation
# ### Why this topic?
# We selected this topic because there is a growing public perception that plane accidents have increased since end of the 2024. However, we are uncertain whether this perception is driven by an actual rise in incidents or by increased media attention. By exploring the underlying causes of flight accidents, we hope to provide data-driven insights that clarify trends in aviation safety and contribute to discussions on how to enhance airline security and risk management.
#
# ### 3 Key Questions and What We Hope to Learn
# 1. What are the most common causes of flight accidents, and how have these causes changed over time?
#     * By analyzing historical data, we aim to determine whether certain factors (e.g., mechanical failure, weather conditions, human error) have become more or less frequent contributors to flight accidents. This could help identify emerging risks and areas for improvement in aviation safety.
# 2. What are the most common factors contributing to flight accidents?
#     * By analyzing historical accident data, we aim to identify the leading causes, such as weather conditions, mechanical failures, human error, or operational inefficiencies.
# 3. Is there a correlation between media coverage and public perception of aviation safety?
#     * We seek to understand whether heightened media reporting on aviation incidents correlates with increased public fear, regardless of actual accident trends.

# %% [markdown]
# ## [TODO] Data Sources & Description
# * https://asn.flightsafety.org/database/
# * https://www.kaggle.com/datasets/ahmadrafiee/airports-airlines-planes-and-routes-update-2024/data?select=routes.csv
#
# Explain how the two (or more) datasets complement each other
#
# For each data source, list the variables of interest, the size of the data sets, missing values, etc.

# %% [markdown]
# ## Data Manipulation
# This is where you merge your data sets, as well as create new columns (if appropriate)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
import glob

path = "data/ASN/"
file_pattern = f"{path}accident_details_*.csv"

csv_files = glob.glob(file_pattern)

dfs = [pd.read_csv(file) for file in csv_files]
df = pd.concat(dfs, ignore_index=True)
df
# Out:
#           Time                                Type                     Date  \
# 0        11:16      British Aerospace BAe-125-700A    Monday 2 January 2006
# 1        12:40                       Antonov An-26   Tuesday 3 January 2006
# 2        08:00           Cessna 560 Citation Ultra  Thursday 5 January 2006
# 3        02:00            Beechcraft A100 King Air  Thursday 5 January 2006
# 4        17:04                Douglas C-54G (DC-4)  Thursday 5 January 2006
# ...        ...                                 ...                      ...
# 4123  01:30 LT                      Boeing 767-224     Monday 22 April 2002
# 4124  14:36 LT               Cessna 560 Citation V   Thursday 25 April 2002
# 4125       NaN                     Boeing 707-366C     Friday 26 April 2002
# 4126     03:00         McDonnell Douglas DC-10-40F   Saturday 27 April 2002
# 4127       NaN                       Antonov An-12    Tuesday 30 April 2002
#
#                 Owner.operator Registration  \
# 0                        Avcom       P4-AOD
# 1          Ruwenzori Air Asala          NaN
# 2                      NetJets       N391QS
# 3       North Country Aviation       N700NC
# 4              Buffalo Airways       C-GXKN
# ...                        ...          ...
# 4123      Continental Airlines       N68160
# 4124  Executive Jet Managemant       N560RP
# 4125         Hewa Bora Airways       9Q-CKB
# 4126       Centurion Air Cargo       N141WE
# 4127        Aerovista Airlines       ST-AQP
#
#                                         MSN  \
# 0                                    257153
# 1                                       NaN
# 2                                  560-0493
# 3                                     B-138
# 4                                     36090
# ...                                     ...
# 4123                              30439/851
# 4124  560-0158Total airframe hrs:3927 hours
# 4125                              19844/744
# 4126                              46661/224
# 4127                                4342305
#
#                      Year.of.manufacture          Fatalities  \
# 0                                   1981    3 / Occupants: 3
# 1                                    NaN      0 / Occupants:
# 2      1985Total airframe hrs:6276 hours    0 / Occupants: 7
# 3     1972Total airframe hrs:13033 hours    0 / Occupants: 3
# 4                                   1946    0 / Occupants: 4
# ...                                  ...                 ...
# 4123   2001Total airframe hrs:2076 hours  0 / Occupants: 122
# 4124                                 NaN    0 / Occupants: 2
# 4125                                1973    0 / Occupants: 3
# 4126                                1976    0 / Occupants: 5
# 4127                                1964    0 / Occupants: 4
#
#       Other.fatalities           Aircraft.damage  Category  \
# 0                    0    Destroyed, written off  Accident
# 1                    0               Substantial  Accident
# 2                    0     Substantial, repaired  Accident
# 3                    0    Destroyed, written off  Accident
# 4                    0  Substantial, written off  Accident
# ...                ...                       ...       ...
# 4123                 0                       NaN  Accident
# 4124                 0               Substantial  Accident
# 4125                 0    Destroyed, written off  Accident
# 4126                 0     Substantial, repaired  Accident
# 4127                 0    Destroyed, written off  Accident
#
#                                                Location     Phase  \
# 0         4,3 km W of Kharkov Airport (HRK) -   Ukraine  Approach
# 1                Fataki -   Congo (Democratic Republic)  En route
# 2     Minocqua-Noble F. Lee Airport, WI (ARV) -   Un...   Landing
# 3     Sault Ste Marie Municipal-Sanderson Airport, M...   Landing
# 4             Norman Wells Airport, NT (YVQ) -   Canada  En route
# ...                                                 ...       ...
# 4123  75 miles N of San Juan, Puerto Rico -   Atlant...  En route
# 4124  Lake In The Hil, Illinois -   United States of...   Unknown
# 4125  Kinshasa-N'Djili Airport (FIH) -   Congo (Demo...   Landing
# 4126  San Salvador-Comalapa International Airport (S...  Take off
# 4127                                   Heglig -   Sudan  Approach
#
#                                           Nature  \
# 0                              Ferry/positioning
# 1                                        Unknown
# 2     Passenger - Non-Scheduled/charter/Air Taxi
# 3                                      Ambulance
# 4                                          Cargo
# ...                                          ...
# 4123                       Passenger - Scheduled
# 4124                           Ferry/positioning
# 4125                                       Cargo
# 4126                                       Cargo
# 4127                                       Cargo
#
#                                       Departure.airport  \
# 0                Moskva-Sheremetyevo Airport (SVO/UUEE)
# 1                              Bunia Airport (BUX/FZKA)
# 2              Chicago-Executive Airport, IL (PWK/KPWK)
# 3     Traverse City-Cherry Capital Airport, MI (TVC/...
# 4                   Norman Wells Airport, NT (YVQ/CYVQ)
# ...                                                 ...
# 4123  SÃ£o Paulo-Guarulhos International Airport, SP...
# 4124             San Angelo-Mathis Field, TX (SJT/KSJT)
# 4125      Johannesburg International Airport (JNB/FAJS)
# 4126  San Salvador-Comalapa International Airport (S...
# 4127                  Khartoum-Civil Airport (KRT/HSSS)
#
#                                     Destination.airport  \
# 0                            Kharkov Airport (HRK/UKHH)
# 1                                          Aru Airstrip
# 2          Minocqua-Noble F. Lee Airport, WI (ARV/KARV)
# 3     Sault Ste Marie Municipal-Sanderson Airport, M...
# 4                    Yellowknife Airport, NT (YZF/CYZF)
# ...                                                 ...
# 4123  Newark-Liberty International Airport, NJ (EWR/...
# 4124                          LAKE IN THE HIL, IL (3CK)
# 4125                Kinshasa-N'Djili Airport (FIH/FZAA)
# 4126        Guatemala City-La Aurora Airport (GUA/MGGT)
# 4127                          Heglig Airport (HEG/HSHG)
#
#                                       Confidence.Rating  \
# 0     Information is only available from news, socia...
# 1                                                   NaN
# 2     Accident investigation report completed and in...
# 3     Accident investigation report completed and in...
# 4     Accident investigation report completed and in...
# ...                                                 ...
# 4123  Accident investigation report completed and in...
# 4124  Accident investigation report completed and in...
# 4125  Information verified through data from acciden...
# 4126  Information verified through data from acciden...
# 4127  Information is only available from news, socia...
#
#                                               Narrative  \
# 0     The BAe-125-700A corporate jet was being repos...
# 1     The Antonov An-26 was operating on a flight fr...
# 2     A Cessna 560 Citation Ultra, N391QS, sustained...
# 3     A Beech A100, N700NC, operated as an emergency...
# 4     The C-54 departed Norman Wells at 16:52. Six m...
# ...                                                 ...
# 4123  The airplane was in cruise flight at flight le...
# 4124  The on-demand air-taxi positioning flight sust...
# 4125  Weather at Kinshasa-NDjili Airport was stormy ...
# 4126  At rotation, the flightcrew heard a sound desc...
# 4127  The Antonov was approaching Heglig. When desce...
#
#                       Engine.model Investigating.agency  \
# 0                              NaN                  NaN
# 1                   Ivchenko AI-24                  NaN
# 2     Pratt & Whitney Canada JT15D                 NTSB
# 3           Pratt & Whitney PT6-28                 NTSB
# 4       Pratt & Whitney R-2000-7M2                  TSB
# ...                            ...                  ...
# 4123  General Electric CF6-80C2B4F                 NTSB
# 4124      Pratt & Whitney JT15D-5A                 NTSB
# 4125        Pratt & Whitney JT3D-7                  NaN
# 4126                           NaN                  NaN
# 4127                Ivchenko AI-20                  NaN
#
#                                             detail_link
# 0     https://aviation-safety.net/database/record.ph...
# 1     https://aviation-safety.net/database/record.ph...
# 2     https://aviation-safety.net/database/record.ph...
# 3     https://aviation-safety.net/database/record.ph...
# 4     https://aviation-safety.net/database/record.ph...
# ...                                                 ...
# 4123        https://aviation-safety.net/wikibase/309637
# 4124        https://aviation-safety.net/wikibase/297366
# 4125  https://aviation-safety.net/database/record.ph...
# 4126  https://aviation-safety.net/database/record.ph...
# 4127  https://aviation-safety.net/database/record.ph...
#
# [4128 rows x 21 columns]

# %% [markdown]
# ## Data Visualization
# Produce 3 or more plots that help describe your data.  Choose appropriate visualizations
