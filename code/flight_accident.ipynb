# %% [markdown]
# # Project Title: Flight Accidents Analysis

# %% [markdown]
# ## [TODO] Team Members with uniqname
# * Yufeng Song (yfsong)
# * Ziqi Wang ()
# * Muyu Lin (mlin567)

# %% [markdown]
# ## Overview
# Our project analyzes historical flight accident data to determine trends in aviation safety and identify key factors contributing to accidents. We aim to assess whether the perceived increase in plane accidents this year is due to actual incidents or amplified media coverage. By uncovering patterns, we can help improve aviation safety and inform future risk mitigation strategies.

# %% [markdown]
# ## Motivation
# ### Why this topic?
# We selected this topic because there is a growing public perception that plane accidents have increased since end of the 2024. However, we are uncertain whether this perception is driven by an actual rise in incidents or by increased media attention. By exploring the underlying causes of flight accidents, we hope to provide data-driven insights that clarify trends in aviation safety and contribute to discussions on how to enhance airline security and risk management.
#
# ### 3 Key Questions and What We Hope to Learn
# 1. What are the most common causes of flight accidents, and how have these causes changed over time?
#     * By analyzing historical data, we aim to determine whether certain factors (e.g., mechanical failure, weather conditions, human error) have become more or less frequent contributors to flight accidents. This could help identify emerging risks and areas for improvement in aviation safety.
# 2. What are the most common factors contributing to flight accidents?
#     * By analyzing historical accident data, we aim to identify the leading causes, such as weather conditions, mechanical failures, human error, or operational inefficiencies.
# 3. Is there a correlation between media coverage and public perception of aviation safety?
#     * We seek to understand whether heightened media reporting on aviation incidents correlates with increased public fear, regardless of actual accident trends.

# %% [markdown]
# ## [TODO] Data Sources & Description
# * https://asn.flightsafety.org/database/
# * https://www.kaggle.com/datasets/ahmadrafiee/airports-airlines-planes-and-routes-update-2024/data?select=routes.csv
#
# Explain how the two (or more) datasets complement each other
#
# For each data source, list the variables of interest, the size of the data sets, missing values, etc.

# %% [markdown]
# ## Data Manipulation
# This is where you merge your data sets, as well as create new columns (if appropriate)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 150)

# %%
import glob

path = "../data/"
patterns = [f"{path}accident_details_*.csv", f"{path}*_accident_details.csv"]

csv_files = []
for p in patterns:
    csv_files.extend(glob.glob(p))

dfs = [pd.read_csv(file) for file in csv_files]
df = pd.concat(dfs, ignore_index=True)
df.sample(5)
# Out:
#        Time                                  Type                     Date  \
# 3896  08:30                        Boeing 737-236  Sunday 17 February 2002
# 3515    NaN                       Tupolev Tu-154M   Thursday 15 March 2001
# 6897  10:40                   Antonov An-148-100E    Saturday 5 March 2011
# 5758  12:20                          Let L-410UVP    Monday 2 January 2017
# 5816  11:46      Britten-Norman BN-2A-26 Islander  Wednesday 12 April 2017
#
#                                        Owner.operator Registration  \
# 3896                            Aerolineas Argentinas       LV-ZRE
# 3515                                 Vnukovo Airlines     RA-85619
# 6897  Voronezh Aircraft Production Association - VASO        61708
# 5758                                  Doren Air Congo       9Q-CZR
# 5816                       Air Services Limited - ASL       8R-GAR
#
#              MSN                 Year.of.manufacture          Fatalities  \
# 3896  23168/1077                                1985   0 / Occupants: 96
# 3515      86A738                                1986  3 / Occupants: 174
# 6897       41-03               2011Cycles:32 flights    6 / Occupants: 6
# 5758      851336                                1985    0 / Occupants: 2
# 5816         306  1971Total airframe hrs:15218 hours    0 / Occupants: 2
#
#       Other.fatalities         Aircraft.damage               Category  \
# 3896                 0   Substantial, repaired               Accident
# 3515                 0                 Unknown  Unlawful Interference
# 6897                 0  Destroyed, written off               Accident
# 5758                 0             Substantial               Accident
# 5816                 0             Substantial               Accident
#
#                                                Location     Phase  \
# 3896                         San Juan, SJ -   Argentina  En route
# 3515  Madinah-Mohammad Bin Abdulaziz Airport (MED) -...  En route
# 6897              Garbuzovo, Belgorod region -   Russia  En route
# 5758   Shabunda Airport -   Congo (Democratic Republic)   Landing
# 5816                       Kopinang Airfield -   Guyana   Landing
#
#                                           Nature  \
# 3896                       Passenger - Scheduled
# 3515  Passenger - Non-Scheduled/charter/Air Taxi
# 6897                                        Test
# 5758                                       Cargo
# 5816  Passenger - Non-Scheduled/charter/Air Taxi
#
#                                       Departure.airport  \
# 3896  Santiago-Arturo Merino Benitez Airport (SCL/SCEL)
# 3515  Istanbul-AtatÃ¼rk International Airport (IST/L...
# 6897                   Voronezh-Pridacha Airport (UUOD)
# 5758                   Bukavu-Kavumu Airport (BKY/FZMA)
# 5816                          Mahdia Airport (MHA/SYMD)
#
#                                     Destination.airport  \
# 3896  Buenos Aires/Ezeiza-Ministro Pistarini Airport...
# 3515                           Moskva (unknown airport)
# 6897                   Voronezh-Pridacha Airport (UUOD)
# 5758                            Shabunda Airport (FZMW)
# 5816                           Kopinang Airfield (SYKO)
#
#                                       Confidence.Rating  \
# 3896  Accident investigation report completed and in...
# 3515                                                NaN
# 6897  Accident investigation report completed and in...
# 5758  Information is only available from news, socia...
# 5816  Accident investigation report completed and in...
#
#                                               Narrative  \
# 3896  Aerolineas Argentinas Flight 1289 suffered a c...
# 3515  Three Chechen hijackers took control of the ai...
# 6897  An Antonov 148-100E jet, registered 61708, was...
# 5758  A Let L-410 cargo plane, operated by Doren Air...
# 5816  The BN-2A-26 Islander aircraft departed from A...
#
#                   Engine.model Investigating.agency  \
# 3896  Pratt & Whitney JT8D-15A                  NaN
# 3515    Soloviev D-30KU-154-II                  NaN
# 6897                       NaN                  NaN
# 5758                       NaN                  NaN
# 5816       Lycoming O-540-E4C5             GCAA-AIT
#
#                                             detail_link
# 3896  https://aviation-safety.net/database/record.ph...
# 3515  https://aviation-safety.net/database/record.ph...
# 6897  https://aviation-safety.net/database/record.ph...
# 5758  https://aviation-safety.net/database/record.ph...
# 5816  https://aviation-safety.net/database/record.ph...

# %%
df.columns = [col.replace('.', '_') for col in df.columns]
df.columns
# Out:
# Index(['Time', 'Type', 'Date', 'Owner_operator', 'Registration', 'MSN',
#        'Year_of_manufacture', 'Fatalities', 'Other_fatalities',
#        'Aircraft_damage', 'Category', 'Location', 'Phase', 'Nature',
#        'Departure_airport', 'Destination_airport', 'Confidence_Rating',
#        'Narrative', 'Engine_model', 'Investigating_agency', 'detail_link'],
#       dtype='object')

# %% [markdown]
# ### Data Fields Documentation
#
# 1. **Time (string)** – The local time of the accident occurrence, unless otherwise stated.
# 2. **Type (string)** – The aircraft manufacturer and exact model involved in the accident.
# 3. **Date (string)** – The date of the accident in the format `DD MMM YYYY`.
# 4. **Owner_operator (string)** – The company, organization, or individual operating the aircraft at the time of the accident.
# 5. **Registration (string)** – The aircraft’s official registration mark at the time of the accident.
# 6. **MSN (string)** – Manufacturer Serial Number (MSN) or construction number of the aircraft.
# 7. **Year_of_manufacture (integer)** – The year the aircraft was manufactured.
# 8. **Fatalities (integer)** – Number of people on board who died as a direct result of the accident.
# 9. **Other_fatalities (integer)** – Number of fatalities on the ground or in another aircraft involved in the accident.
# 10. **Aircraft_damage (string)** – Description of the aircraft's damage level (e.g., `Written off`, `Substantial`, `Minor`, `None`).
# 11. **Category (string)** – Classification of the accident based on its nature and impact.
# 12. **Location (string)** – The exact or approximate location where the accident occurred.
# 13. **Phase (string)** – The phase of flight during which the accident occurred (e.g., `Takeoff`, `Cruise`, `Landing`).
# 14. **Nature (string)** – The type of flight operation at the time of the accident (e.g., `Passenger`, `Cargo`, `Military`).
# 15. **Departure_airport (string)** – The last airport the aircraft departed from before the accident.
# 16. **Destination_airport (string)** – The scheduled or intended destination airport.
# 17. **Confidence_Rating (integer or float)** – A rating indicating the reliability of the accident data.
# 18. **Narrative (string)** – A brief description of the accident and relevant details.
# 19. **Engine_model (string)** – The type and model of the aircraft's engine(s).
# 20. **Investigating_agency (string)** – The authority responsible for investigating the accident.
# 21. **detail_link (string)** – A URL linking to more detailed information about the accident.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7754 entries, 0 to 7753
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Time                  6287 non-null   object
#  1   Type                  7754 non-null   object
#  2   Date                  7754 non-null   object
#  3   Owner_operator        7715 non-null   object
#  4   Registration          7591 non-null   object
#  5   MSN                   7477 non-null   object
#  6   Year_of_manufacture   6947 non-null   object
#  7   Fatalities            7754 non-null   object
#  8   Other_fatalities      7754 non-null   int64
#  9   Aircraft_damage       6886 non-null   object
#  10  Category              7704 non-null   object
#  11  Location              7754 non-null   object
#  12  Phase                 7748 non-null   object
#  13  Nature                7749 non-null   object
#  14  Departure_airport     7031 non-null   object
#  15  Destination_airport   7061 non-null   object
#  16  Confidence_Rating     6786 non-null   object
#  17  Narrative             7754 non-null   object
#  18  Engine_model          6095 non-null   object
#  19  Investigating_agency  4522 non-null   object
#  20  detail_link           7754 non-null   object
# dtypes: int64(1), object(20)
# memory usage: 1.2+ MB

# %%
df.Departure_airport.value_counts()
# Out:
# Departure_airport
# -                                                                  573
# Atlanta Hartsfield-Jackson International Airport, GA (ATL/KATL)     48
# Boston-Logan International Airport, MA (BOS/KBOS)                   39
# Toronto-Pearson International Airport, ON (YYZ/CYYZ)                39
# New York-La Guardia Airport, NY (LGA/KLGA)                          37
#                                                                   ...
# GPOC Unity Airstrip                                                  2
# Busan-Gimhae (Pusan) International Airport (PUS/RKPK)                2
# Louisville-Muhammad Ali International Airport, KY (SDF/KSDF)         2
# Rottnest Island, WA                                                  2
# Purari                                                               2
# Name: count, Length: 1281, dtype: int64

# %%
list(df.Destination_airport.unique())
# Out:
# ['Kharkov Airport (HRK/UKHH)',
#  'Aru Airstrip',
#  'Minocqua-Noble F. Lee Airport, WI (ARV/KARV)',
#  'Sault Ste Marie Municipal-Sanderson Airport, MI (SSM/KANJ)',
#  'Yellowknife Airport, NT (YZF/CYZF)',
#  'Urmia (Orumiyeh) Airport (OMH/OITR)',
#  'Pensacola NAS, FL (NPA/KNPA)',
#  'San JosÃ©-Tobias Bolanos International Airport (SYQ/MRPV)',
#  nan,
#  'Freiburg Im Breisgau Airfield (EDTF)',
#  "Kinshasa-N'Djili Airport (FIH/FZAA)",
#  'Anchorage-Ted Stevens International Airport, AK (ANC/PANC)',
#  'Houston-George Bush Intercontinental Airport, TX (IAH/KIAH)',
#  'KoÂ\x9aice-Barca Airport (KSC/LZKZ)',
#  'Lanseria International Aerodrome (FALA) in South Africa.',
#  'Vancouver International Airport, BC (YVR/CYVR)',
#  'Matsuyama Airport (MYJ/RJOM)',
#  'Mbuji-Mayi Airport (MJM/FZWA)',
#  'Carlsbad-McClellan-Palomar Airport, CA (CLD/KCRQ)',
#  'Caloundra Airport, QLD (CUD/YCDR)',
#  'Cap Haitien Airport (CAP/MTCH)',
#  'Burnsville-Mountain Air Airport, NC',
#  'Sydney-Kingsford Smith International Airport, NSW (SYD/YSSY)',
#  'Myrtle Beach-Grand Strand Airport, SC (CRE/KCRE)',
#  'Milwaukee-General Mitchell Airport, WI (MKE/KMKE)',
#  'Harlingen-Valley International Airport, TX (HRL/KHRL)',
#  'Philadelphia International Airport, PA (PHL/KPHL)',
#  'Aspen-Pitkin County Airport, CO (ASE/KASE)',
#  'Fort Pierce-Saint Lucie County Airport, FL (FPR/KFPR)',
#  'Aweil Airport (HSAW)',
#  '-',
#  'London-Luton Airport (LTN/EGGW)',
#  'Tampa International Airport, FL (TPA/KTPA)',
#  'Sulaymaniyah International Airport (ISU/ORSU)',
#  'London-Heathrow Airport (LHR/EGLL)',
#  'Fort Myers-Southwest Florida International Airport, FL (RSW/KRSW)',
#  'Beluga Airport, AK (BVU/PABG)',
#  'Kamonya',
#  'Surabaya-Juanda Airport (SUB/WARR)',
#  'Sal-Amilcar Cabral International Airport (SID/GVAC)',
#  'Canaima Airport (CAJ/SVCN)',
#  'Santa Cruz-Viru Viru International Airport (VVI/SLVR)',
#  'Dallas-Love Field, TX (DAL/KDAL)',
#  'Brussel-Zaventem Airport (BRU/EBBR)',
#  'Bangalore-Hindustan Airport (BLR/VOBG)',
#  'Sault Ste. Marie-Chippewa County Airport, MI (CIU/KCIU)',
#  'New York-John F. Kennedy International Airport, NY (JFK/KJFK)',
#  'SARI',
#  'San Fernando Airport, BA (FDO/SADF)',
#  'Old Fangak',
#  'Butte Airport, MT (BTM/KBTM)',
#  'Sevilla Airport (SVQ/LEZL)',
#  'Charlotte-Douglas Airport, NC (CLT/KCLT)',
#  'Nasiriyah-Tallil Air Base (XNH/ORTL)',
#  'Macas Airport (XMS/SEMC)',
#  'Ontario International Airport, CA (ONT/KONT)',
#  'Sharjah Airport (SHJ/OMSJ)',
#  'Moskva-Domodedovo Airport (DME/UUDD)',
#  'Rio de Janeiro-Santos Dumont Airport, RJ (SDU/SBRJ)',
#  'Ramstein Airport (RMS/ETAR)',
#  'Seattle, WA (SEA)',
#  'Marsabit Airport (RBT/HKMB)',
#  'Kozlovets',
#  'Haydom Airstrip',
#  'Dayton-James Cox Dayton International Airport, OH (DAY/KDAY)',
#  'Harrisburg International Airport, PA (MDT/KMDT)',
#  'GuayaramerÃ\xadn Airport (GYA/SLGY)',
#  'Shanghai-Pudong International Airport (PVG/ZSPD)',
#  'Alexandria Airport (ALY/HEAX)',
#  'Tersky',
#  "N'Djamena Airport (NDJ/FTTJ)",
#  'Bost/Lashkar Gah Airport (BST/OABT)',
#  'Dallas/Fort Worth International Airport, TX (DFW/KDFW)',
#  'Amisi Airport',
#  'Bunia Airport (BUX/FZKA)',
#  'Zwedru Airport',
#  'Adler/Sochi Airport (AER/URSS)',
#  'Ujung Pandang-Hasanudin Airport (UPG/WAAA)',
#  'Caracas-SimÃ³n BolÃ\xadvar International Airport (CCS/SVMI)',
#  'Adana Airport (ADA/LTAF)',
#  'Rochester-Monroe County Airport, NY (ROC/KROC)',
#  'Washington-Dulles International Airport, DC (IAD/KIAD)',
#  'Manado-Sam Ratulangi Airport (MDC/WAMM)',
#  'Sandy Bay Airport, SK',
#  'Fort St. John Airport, BC (YXJ/CYXJ)',
#  'Guadalajara-Don Miguel Hidalgo y Costilla International Airport (GDL/MMGL)',
#  'Balad Air Base (ORBD)',
#  'Columbus (unknown airport), OH',
#  'Sangata-Tanjung Bara Airport (WRLJ)',
#  'Long Beach Municipal Airport, CA (LGB/KLGB)',
#  'Kuching Airport (KCH/WBGG)',
#  'Newcastle Airport (NCL/EGNT)',
#  'Nixon Fork Mine, AK',
#  'Paderborn-Lippstadt',
#  'Johannesburg-O.R. Tambo International Airport (JNB/FAOR)',
#  'Barcelona-El Prat Airport (BCN/LEBL)',
#  'Butler County/K. W. Scholter Field Airport, PA (BTP/KBTP)',
#  'El Fasher Airport (ELF/HSFS)',
#  'St. Moritz-Samedan Airport (SMV/LSZS)',
#  'Phoenix-Sky Harbor International Airport, AZ (PHX/KPHX)',
#  'Paris-Charles de Gaulle Airport (CDG/LFPG)',
#  'SÃ£o Paulo-Congonhas Airport, SP (CGH/SBSP)',
#  'Staunton-Shenandoah Valley Airport, VA (SHD/KSHD)',
#  'Miami International Airport, FL (MIA/KMIA)',
#  'Grand Turk Island Airport (GDT/MBJT)',
#  'Bozeman-Gallatin Field, MT (BZN/KBZN)',
#  'Cebu Airport (CEB/RPVM)',
#  'Scottsbluff-Western Nebraska Regional Airport, NE (BFF/KBFF)',
#  'Berbegamau Airstrip, QC',
#  'Berlin-SchÃ¶nefeld Airport (SXF/EDDB)',
#  'Walikale Airstrip',
#  'Nouadhibou Airport (NDB/GQPP)',
#  'Cleveland-Hopkins International Airport, OH (CLE/KCLE)',
#  "Chicago-O'Hare International Airport, IL (ORD/KORD)",
#  'Geneina Airport (EGN/HSCN)',
#  'Valencia Airport (VLN/SVVA)',
#  'Ruhnu Airport (EERU)',
#  'Yogyakarta-Adisutjipto Airport (JOG/WARJ)',
#  'Mogadishu International Airport (MGQ/HCMM)',
#  'Dhaka-Zia International Airport (DAC/VGZR)',
#  'Kochi Airport (KCZ/RJOK)',
#  'Sao Paulo,  (SBGR)',
#  'Johannesburg International Airport (JNB/FAJS)',
#  'Kish Island Airport (KIH/OIBK)',
#  'Beverly Airport, MA (BVY/KBVY)',
#  'Samara Airport (KUF/UWWW)',
#  'London-Gatwick Airport (LGW/EGKK)',
#  'Rifle-Garfield County Airport, CO (RIL)',
#  'Istanbul-AtatÃ¼rk International Airport (IST/LTBA)',
#  'Djibouti-Ambouli Airport (JIB/HDAM)',
#  'Thompson Airport, MB (YTH/CYTH)',
#  'Hampton-Newport News/Williamsburg Airport, VA (PHF/KPHF)',
#  'Orlando-Central Florida Regional Airport, FL (SFB/KSFB)',
#  'Guatemala City-La Aurora Airport (GUA/MGGT)',
#  'Hoskins Airport (HKN/AYHK)',
#  'Khartoum-Civil Airport (KRT/HSSS)',
#  'Mount Hale Airport, WA (YMHE)',
#  'MohÃ©li-Bandar es Eslam Airport (NWA/FMCI)',
#  'Istanbul-Sabiha GÃ¶kÃ§en International Airport (SAW/LTFJ)',
#  'Makassar-Sultan Hasanuddin International Airport (UPG/WAAA)',
#  'Traverse City-Cherry Capital Airport, MI (TVC/KTVC)',
#  'Los Angeles International Airport, CA (LAX/KLAX)',
#  'Tel Aviv-Ben Gurion International Airport (TLV/LLBG)',
#  'Atlanta Hartsfield-Jackson International Airport, GA (ATL/KATL)',
#  "Governor's Harbour Airport (GHB/MYEM)",
#  'Kopinang Airfield (SYKO)',
#  'Baltimore/Washington International Thurgood Marshall Airport, MD (BWI/KBWI)',
#  'Selway Lodge Airstrip, ID',
#  'San Juan-Luis MuÃ±oz MarÃ\xadn International Airport (SJU/TJSJ)',
#  'Dillon Airport, MT (DLN/KDLN)',
#  'Nairobi-Jomo Kenyatta International Airport (NBO/HKJK)',
#  'Santa Katarina-Mount Sinai Airport (SKV/HESC)',
#  'Trenton Canadian Forces Base, ON (YTR/CYTR)',
#  'Brazzaville-Maya Maya Airport (BZV/FCBB)',
#  'Goma Airport (GOM/FZNA)',
#  'Detroit, MI (DTW)',
#  'Kalispell-Glacier Park International Airport, MT (FCA/KGPI)',
#  'Toronto-Pearson International Airport, ON (YYZ/CYYZ)',
#  'Acarigua Airport (AGV/SVAC)',
#  'Shiraz Airport (SYZ/OISS)',
#  'Masbate Airport (MBT/RPVJ)',
#  'Los Roques Airport (LRV/SVRS)',
#  'Colombo-Bandaranaike International Airport (CMB/VCBI)',
#  'Detroit-Metropolitan Wayne County Airport, MI (DTW/KDTW)',
#  'Bacau Airport (BCM/LRBC)',
#  'Maribor Airport (MBX/LJMB)',
#  'Kauai Island/Lihue Airport, HI (LIH/PHLI)',
#  'Bethel Airport, AK (BET/PABE)',
#  'Huambo Airport (NOV/FNHU)',
#  'Miroslawiec Air Base (EPMI)',
#  'Teresita Airport',
#  'Pointe-Noire Airport (PNR/FCPP)',
#  'Bulawayo-Joshua Mqabuko Nkomo International Airport (BUQ/FVJN)',
#  'Long Apung Airport (LPU/WALP)',
#  'Merauke-Mopah Airport (MKQ/WAKK)',
#  'BogotÃ¡-Eldorado Airport (BOG/SKBO)',
#  'Chicago-Midway Airport, IL (MDW/KMDW)',
#  'Bilogai/Sugapa Airport (ZGP/WAYB)',
#  'Brooksville-Hernando County Airport, FL (KBKV)',
#  'Lincoln Municipal Airport, NE (LNK/KLNK)',
#  'Cobija-E. Beltram Airport (CIJ/SLCO)',
#  'Nassau-Lynden Pindling International Airport (NAS/MYNN)',
#  'Sint Maarten-Juliana Airport (SXM/TNCM)',
#  'Coventry-Baginton Airport (CVT/EGBE)',
#  'Amsterdam-Schiphol International Airport (AMS/EHAM)',
#  'Denver International Airport, CO (DEN/KDEN)',
#  'Trondheim-VÃ¦rnes Airport (TRD/ENVA)',
#  'Darwin Airport, NT (DRW/YPDN)',
#  'NuquÃ\xad-Reyes Murillo Airport (NQU/SKNQ)',
#  'Punta Cana International Airport (PUJ/MDPC)',
#  'Christchurch International Airport (CHC/NZCH)',
#  'Osaka-Kansai International Airport (KIX/RJBB)',
#  'Leesburg Executive Airport, VA (JYO/KJYO)',
#  'East Hampton Airport, NY (HTO/KHTO)',
#  'Kandahar Airport (KDH/OAKN)',
#  'Minsk-2 International Airport (MSQ/UMMS)',
#  'Greenville-Spartanburg Airport, SC (GSP/KGSP)',
#  'New York-La Guardia Airport, NY (LGA/KLGA)',
#  'Puerto Ordaz/Ciudad Guayana-General Manuel Carlos Piar Airport (PZO/SVPR)',
#  'Myitkyina Airport (MYT/VYMK)',
#  'Aniak Airport, AK (ANI/PANI)',
#  'Orlando International Airport, FL (MCO/KMCO)',
#  'Kayenta-Peabody Bedard Field Airport, AZ',
#  'Manila-Ninoy Aquino International Airport (MNL/RPLL)',
#  'Rio de Janeiro/GaleÃ£o-Antonio Carlos Jobim International Airport, RJ (GIG/SBGL)',
#  'Venice-Marco Polo Airport (VCE/LIPZ)',
#  'Mankato Municipal Airport, MN (MKT/KMKT)',
#  'Wamena Airport (WMX/WAJW)',
#  'Cape Town International Airport (CPT/FACT)',
#  'Beijing-Capital International Airport (PEK/ZBAA)',
#  'Augusta-Daniel Field, GA (DNL/KDNL)',
#  'Batam-Hang Nadim Airport (BTH/WIDD)',
#  'SÃ©tif-Ain Arat Airport (QSF/DAAS)',
#  'Bebi Airstrip (DNBB)',
#  'Udaipur-Dabok Airport (UDR/VAUD)',
#  'Mannheim Airport (MHG/EDFM)',
#  'QuÃ©bec City Jean Lesage International Airport, QC (YQB/CYQB)',
#  'Limoges-Bellegarde Airport (LIG/LFBL)',
#  'Pau-Uzein Airport (PUF/LFBP)',
#  'Odense-Beldringe Airport (ODE/EKOD)',
#  'Mwanza Airport (MWZ/HTMW)',
#  'Lawa-Antino Airport',
#  'Hanoi-Gia Lam Airport (VVGL)',
#  'Brisbane International Airport, QLD (BNE/YBBN)',
#  'Antalya Airport (AYT/LTAI)',
#  'Potsdam Municipal-Damon field, NY (KPTD)',
#  'White Plains-Westchester County Airport, NY (HPN/KHPN)',
#  'Kisangani-Bangoka International Airport (FKI/FZIC)',
#  'Havana-JosÃ© MartÃ\xad International Airport (HAV/MUHA)',
#  'Greenville Airport, MS (GLH/KGLH)',
#  'Spearfish-Black Hills Airport, SD (SPF/KSPF)',
#  'South Perth, WA',
#  'Los Angeles International Airport (LAX/KLAX), CA, USA',
#  'Ubatuba Airport, SP (UBT/SDUB)',
#  'Minneapolis-St. Paul International Airport, MN (MSP/KMSP)',
#  'Jebel-Boma County Airstrip',
#  'Kongolo Airport (KOO/FZRQ)',
#  'Hong Kong-Chek Lap Kok International Airport (HKG/VHHH)',
#  'Juba Airport (JUB/HJJJ)',
#  'Washington-Ronald Reagan National Airport, DC (DCA/KDCA)',
#  'Springfield-Branson National Airport, MO (SGF/KSGF)',
#  'Seattle/Tacoma International Airport, WA (SEA/KSEA)',
#  'Puerto Vallarta-Gustavo D. Ordaz Airport (PVR/MMPR)',
#  'Arkalyk Airport (AYK/UAUR)',
#  'Kerema Airport (KMA/AYKM)',
#  'Nome Airport, AK (OME/PAOM)',
#  'Scottsdale Airport, AZ (SCF/KSDL)',
#  'Oakland International Airport, CA (OAK/KOAK)',
#  'Palatka Municipal/Lt Kay Larkin Field Airport, FL (28J)',
#  'Telluride Regional Airport, CO (TEX/KTEX)',
#  'Tony Camp',
#  'Wilmington-New Hanover County International Airport, NC (ILM/KILM)',
#  'Iquitos Airport (IQT/SPQT)',
#  'Caticlan-Malay Airport (MPH/RPVE)',
#  'Bosaso-Bender Qassim International Airport (BSA/HCMF)',
#  'Makhachkala Airport (MCX/URML)',
#  'Nizhniy Novgorod Airport (GOJ/UWGG)',
#  'Charlotte-Douglas International Airport, NC (CLT/KCLT)',
#  'Island Lake/Garden Hill Airport, MB (YIV/CYIV)',
#  'Oradea Airport (OMR/LROD)',
#  'Tehran-Mehrabad Airport (THR/OIII)',
#  'Barnaul Airport (BAX/UNBB)',
#  'Lubbock Preston Smith International Airport, TX (LBB/KLBB)',
#  'Bagram Air Base (OAI/OAIX)',
#  'Delhi-Indira Gandhi International Airport (DEL/VIDP)',
#  'Deschambeault Lake, SK',
#  'Mojave-Kern County Airport, CA (MHV/KMHV)',
#  'Ciudad Victoria Airport (CVM/MMCV)',
#  'TromsÃ¸/Langnes Airport (TOS/ENTC)',
#  'Manaus-Eduardo Gomes International Airport, AM (MAO/SBEG)',
#  'Bologna Airport (BLQ/LIPE)',
#  "Santo Domingo-Las AmÃ©ricas JosÃ© Francisco PeÃ±a GÃ³mez Int'l Airport (SDQ/MDSD)",
#  'Eskisehir-Anadolu University Airport (AOE/LTBY)',
#  'Pskov Airport (PKV/ULOO)',
#  'Boma Airstrip',
#  'Heraklion-N. Kazantzakis Airport (HER/LGIR)',
#  'Buffalo Niagara International Airport, NY (BUF/KBUF)',
#  'London City Airport (LCY/EGLC)',
#  'Kotzebue-Ralph Wien Memorial Airport, AK (OTZ/PAOT)',
#  'Guasdualito-Vare Maria Airport (GDO/SVGD)',
#  'Isfahan/Shahin Shahr-Hesa Air Base (IFH/OIFE)',
#  'QuibdÃ³-El CaraÃ±o Airport (UIB/SKUI)',
#  'Palanquero-German Olano Air Base (PAL/SKPQ)',
#  'Tokyo-NRT',
#  'Nikolaev Airport (NLV/UKON)',
#  'Bukhara Airport (BHK/UTSB)',
#  'Kansas City-Charles B. Wheeler Downtown Airport, MO (MKC/KMKC)',
#  'Timisoara Airport (TSR/LRTR)',
#  'Valera-Carvajal Airport (VLV/SVVL)',
#  'Winnipeg-James Armstrong Richardson International Airport, MB (YWG/CYWG)',
#  'Phitsanulok Airport (PHS/VTPP)',
#  'Jakarta-Soekarno-Hatta International Airport (CGK/WIII)',
#  'Al Udeid Air Base (XJD/OTBH)',
#  'Layfayette, LA',
#  'Quito-Mariscal Sucre Airport (UIO/SEQU)',
#  'Dubai Airport (DXB/OMDB)',
#  'Tokyo-Narita Airport (NRT/RJAA)',
#  'Salt Lake City International Airport, UT (SLC/KSLC)',
#  'Gdynia-Babie Doly Airport (QYD/EPOK)',
#  'Maconacon Airport',
#  'Bandung-Husein Sastranegara International Airport (BDO/WICC)',
#  'Sam Neua Airport (NEU/VLSN)',
#  'Santiago de Chile - SCL',
#  'Ciudad BolÃ\xadvar Airport (CBL/SVCB)',
#  'McAllen-Miller International Airport, TX (MFE/KMFE)',
#  'Montego Bay-Sangster International Airport (MBJ/MKJS)',
#  'Frederick Municipal Airport, MD (FDK/KFDK)',
#  'Ottawa-Macdonald-Cartier International Airport, ON (YOW/CYOW)',
#  'Alamogordo Municipal Airport, NM (ALM/KALM)',
#  'Saint Thomas-Cyril E. King Airport (STT/TIST)',
#  'Harare Airport (HRE/FVHA)',
#  'Yakutsk Airport (YKS/UEEE)',
#  'Seongmu Air Base (RKTE)',
#  'Wichita Dwight D. Eisenhower National Airport, KS (ICT/KICT)',
#  'Langeoog Airfield (LGO/EDWL)',
#  'Frankfurt International Airport (FRA/EDDF)',
#  'Riyadh-King Khalid International Airport (RUH/OERK)',
#  'Utila Airport (UII/MHUT)',
#  'Carti Airport (CTE)',
#  'Grand Cayman Island-Owen Roberts International Airport (GCM/MWCR)',
#  'San Juan, PR',
#  'Madiun-Iswahyudi Airport (WARI)',
#  'Somerset-Lake Cumberland Regional Airport, KY (SME/KSME)',
#  'Heglig Airport (HEG/HSHG)',
#  'Chicago-Executive Airport, IL (PWK/KPWK)',
#  'Kearney Regional Airport, NE (EAR/KEAR)',
#  'Maun Airport (MUB/FBMN)',
#  'Marsh Harbour International Airport (MHH/MYAM)',
#  'Chihuahua-Gen Fierro Villalobos Airport (CUU/MMCU)',
#  'Newark-Liberty International Airport, NJ (EWR/KEWR)',
#  'Moba Airport (BDV/FZRB)',
#  'Koolan Island Airport, WA (YKLI)',
#  'Sioux Gateway Airport, IA (SUX/KSUX)',
#  'Luxembourg-Findel Airport (LUX/ELLX)',
#  'Tijuana-Rodriguez Airport (TIJ/MMTJ)',
#  'Mashhad Airport (MHD/OIMM)',
#  'Waterkloof Air Force Base (WKF/FAWK)',
#  'Senador JosÃ© PorfÃ\xadrio-Wilma Rebelo Airfield, PA (SNWR)',
#  'Addis Ababa-Bole Airport (ADD/HAAB)',
#  'Zamboanga Airport (ZAM/RPMZ)',
#  'Luanda-4 de Fevereiro Airport (LAD/FNLU)',
#  'Olyokminsk Airport (OLZ/UEMO)',
#  'Grenoble-Saint Geoirs Airport (GNB/LFLS)',
#  'Napoli Airport (NAP/LIRN)',
#  'Nuevo Laredo-Quetzalcoatl International Airport (NLD/MMNL)',
#  'Samarinda Airport (SRI/WALS)',
#  'Vail-Eagle County Airport, CO (EGE/KEGE)',
#  'Hollywood Burbank Airport, CA (BUR/KBUR)',
#  'Karlstad Airport (KSD/ESOK)',
#  'SÃ£o Paulo-Campo de Marte Airport, SP (SBMT)',
#  'Kipnuk Airport, AK (KPN/PAKI)',
#  'Sacramento International Airport, CA (SMF/KSMF)',
#  'Dubrovnik Airport (DBV/LDDU)',
#  'Bergen-Flesland Airport (BGO/ENBR)',
#  'Taipei-Taiwan Taoyuan International Airport (TPE/RCTP)',
#  'Port Hedland Airport, WA (PHE/YPPD)',
#  'Cairns, QLD',
#  'Rio de Janeiro (unknown airport), RJ',
#  'Palm Beach AFB, FL (PBI/KPBI)',
#  'Port Harcourt Airport (PHC/DNPO)',
#  'Old Harbor Airport, AK (OLH)',
#  'Tallinn-Ã\x9clemiste Airport (TLL/EETN)',
#  'Libreville Airport (LBV/FOOL)',
#  'Moncton/Greater Moncton International Airport, NB (YQM/CYQM)',
#  'Wajir Airport (WJR/HKWJ)',
#  'Huatulco-BahÃ\xadas de Huatulco International Airport (HUX/MMBT)',
#  'Peoria-Greater Peoria Airport, IL (PIA/KPIA)',
#  'Tucson International Airport, AZ (TUS/KTUS)',
#  'Smolensk Air Base (XUBS)',
#  'Monterrey-General Mariano Escobedo International Airport (MTY/MMMY)',
#  'Manokwari-Rendani Airport (MKW/WASR)',
#  'Phaplu Airport (PPL/VNPL)',
#  'Angeles City-Diosdado Macapagal International Airport (CRK/RPLC)',
#  'Exeter Airport',
#  'Nadi International Airport (NAN/NFFN)',
#  'Arlit Airport (RLT/DRZL)',
#  'Elba Island-Marina Di Campo Airport (EBA/LIRJ)',
#  'MitÃº-Fabio Alberto LeÃ³n Bentley Airport (MVP/SKMU)',
#  'Brize Norton RAF Station (BZZ/EGVN)',
#  'Tripoli International Airport (TIP/HLLT)',
#  'Paramaribo-Zorg en Hoop Airport (ORG/SMZO)',
#  'Biscarrosse/Parentis SPB (LFBS)',
#  'Las Piedras-Josefa Camejo Airport (LSP/SVJC)',
#  'Kabul Airport (KBL/OAKB)',
#  'West Memphis, AR (KAWM)',
#  'Cascavel Airport, PR (CAC/SBCA)',
#  'CancÃºn Airport (CUN/MMUN)',
#  'Rotterdam/The Hague Airport (RTM/EHRD)',
#  'Chino Airport, CA (CNO/KCNO)',
#  'Fukuoka Airport (FUK/RJFF)',
#  'Miyazaki Airport (KMI/RJFM)',
#  'Karatayka Airport (ULDT)',
#  'Charallave-Ã\x93scar Machado Zuloaga Airport (SVCS)',
#  'Pokhara International Airport (VNPR)',
#  'Hohn Air Base (ETNH)',
#  'Molokai/Kaunakakai Airport, HI (MKK/PHMK)',
#  'Weeze Airport (NRN/EDLV)',
#  'SÃ£o Paulo-Guarulhos International Airport, SP (GRU/SBGR)',
#  'Tokyo/Narita International Airport (NRT/RJAA), Japan',
#  'Fort Lauderdale-Executive Airport, FL (FXE/KFXE)',
#  'Lankien Airstrip',
#  'North Eleuthera International Airport (ELH/MYEH)',
#  'Bussellton Airport, WA (BQB/YBLN)',
#  'Ulang airstrip',
#  'Waukesha Airport, WI (UES/KUES)',
#  'Tequesquitengo Airport (MMTQ)',
#  'Eliptamin Airport (EPT/AYEL)',
#  'Rochester-Greater Rochester International Airport, NY (ROC)',
#  'Saba-Juancho E. Yrausquin Airport (SAB/TNCS)',
#  'New Orleans-Louis Armstrong International Airport, LA (MSY/KMSY)',
#  'Buenos Aires/Ezeiza-Ministro Pistarini Airport, BA (EZE/SAEZ)',
#  'Houston-William P. Hobby Airport, TX (HOU/KHOU)',
#  'Mount Hagen-Kagamuga Airport (HGU/AYMH)',
#  'Columbus-John Glenn International Airport, OH (CMH/KCMH)',
#  'Fort Hope Airport, ON (YFH/CYFH)',
#  'Mauritius-Sir Seewoosagur Ramgoolam International Airport (MRU/FIMP)',
#  'Calgary International Airport, AB (YYC/CYYC)',
#  'Buena Vista-Central Colorado Regional Airport, CO (KAEJ)',
#  'Amman-Queen Alia International Airport (AMM/OJAI)',
#  'MÃ¼nchen-Franz Josef Strauss Airport (MUC/EDDM)',
#  'Seoul-Incheon International Airport (ICN/RKSI)',
#  'Saltillo-Plan de Guadalupe International Airport (SLW/MMIO), Mexico',
#  'Oklahoma City-Wiley Post Airport, OK (PWA/KPWA)',
#  'Fort Myers-Page Field, FL (FMY/KFMY)',
#  'Belmar/Farmingdale-Monmouth Executive Airport, NJ (BLM/KBLM)',
#  'Kitchener-Region of Waterloo International Airport, ON (YKF/CYKF)',
#  'Dublin Airport (DUB/EIDW)',
#  'Fort Smith Airport, NT (YSM/CYSM)',
#  'Flores-Mundo Maya International Airport (FRS/MGTK)',
#  'Salta-MartÃ\xadn Miguel de GÃ¼emes International Airport, SA (SLA/SASA)',
#  'Haikou Airport (HAK/ZGHK)',
#  'Obaye Airstrip (FZNQ)',
#  'Madrid-Barajas Adolfo SuÃ¡rez Airport (MAD/LEMD)',
#  'Cobar Airport, NSW (CAZ/YCBA)',
#  'Wildwood-Cape May County Airport, NJ (WWD/KWWD)',
#  'Port Hueneme-Point Mugu NAS, CA (NTD/KNTD)',
#  'Maleo Airport (MOH/WAFO)',
#  'Mweya Airport (HUMW)',
#  'Tokyo-Haneda Airport (HND/RJTT)',
#  'Niigata Airport (KIJ/RJSN)',
#  'San Marcos Regional Airport, TX (KHYI)',
#  'Mar del Plata-Astor Piazzolla International Airport, BA (MDQ/SAZM)',
#  'Cairns Airport, QLD (CNS/YBCS)',
#  'Livingston-Mission Field, MT (LVM/KLVM)',
#  'Ceelbarde Airstrip',
#  'Mekele Airport (MQX/HAMK)',
#  'Tashkent-Islam Karimov International Airport (TAS/UTTT)',
#  'Kasese Airport',
#  'Angra dos Reis Airport, RJ (SDAG)',
#  'Diavik Diamond Mine Airport (DVK/CDK2)',
#  'Presque Isle International Airport, ME (PQI/KPQI)',
#  'Bangkok/Suvarnabhumi Airport (BKK/VTBS), Thailand',
#  'Tacoma Narrows Airport, WA (TIW/KTIW)',
#  'Las Vegas-Harry Reid International Airport, NV (LAS/KLAS)',
#  'Malakal Airport (MAK/HJMK)',
#  'Naples Airport, FL (APF/KAPF)',
#  'Leipzig Airport (LEJ/EDDP)',
#  'Puerto Escondido Airport (PXM/MMPS)',
#  'Isabela-General Villamil Airport (IBB/SEII)',
#  'Concord Regional Airport, NC (USA/KJQF)',
#  'DÃ¼sseldorf International Airport (DUS/EDDL)',
#  'Miami Seaplane Base (X44)',
#  'San Francisco, CA (SFO)',
#  'Alenquer-Fazenda TambaÃº, PA (SD8G)',
#  'Arlington Municipal Airport, TX (KGKY)',
#  'Ukunda Airport (UKA/HKUK)',
#  'Katchungu-Tchambogo Airstrip',
#  'Belo Horizonte/Pampulha - Carlos Drummond de Andrade Airport, MG (PLU/SBBH)',
#  'Jowhar Airport (HCJH)',
#  'Hot Springs-Ingalls Field, VA (HSP/KHSP)',
#  'Auckland International Airport (AKL/NZAA)',
#  'Plesetsk Air Base',
#  'Charleston International Airport, SC (CHS/KCHS)',
#  'Butembo Airport (FZBM)',
#  'Yida Airstrip',
#  'Panama City-Tocumen International Airport (PTY/MPTO)',
#  'Kangiqsujuaq Airport, QC (YWB/CYKG)',
#  'Asheville Regional Airport, NC (AVL/KAVL)',
#  'Ellington Airport, CT (7B9)',
#  'Halifax-Stanfield International Airport, NS (YHZ/CYHZ)',
#  'Marco Island Airport, FL (MRK/KMKY)',
#  'Montreal-St Hubert Airport, QC (YHU/CYHU)',
#  'Monterrey-Aeropuerto Del Norte (NTR/MMAN)',
#  'Missoula-Johnson-Bell Field, MT (MSO/KMSO)',
#  'Erechim-Comandante Kraemer Airport, RS (ERM/SSER)',
#  'Kobuk/Wien Airport, AK (OBU/PAOB)',
#  'Gap-Tallard Airfield (GAT/LFNA)',
#  'Aksunkar (Kostanay)',
#  'Kilimanjaro Airport (JRO/HTKJ)',
#  'Anjouan-Ouani Airport (AJN/FMCV)',
#  'Bamako Airport (BKO/GABS)',
#  'LTFG',
#  'Porlamar-del Caribe Santiago MariÃ±o International Airport (PMV/SVMG)',
#  'Bishkek-Manas International Airport (FRU/UCFM)',
#  'Palma de Mallorca Airport (PMI/LEPA)',
#  'Singapore-Changi International Airport (SIN/WSSS)',
#  'Billund Airport (BLL/EKBI)',
#  'Abuja-Nnamdi Azikiwe International Airport (ABV/DNAA)',
#  'Koh Samui Airport (USM/VTSM)',
#  'RÃ\xado Grande-Gobernador RamÃ³n Trejo Noel International Airport, TF (RGA/SAWE)',
#  'Mzuzu Airport (ZZU/FWUU)',
#  'USDM',
#  'Spa-La SauveniÃ¨re Airfield (EBSP)',
#  'Fredericton Airport, NB (YFC/CYFC)',
#  'Richmond International Airport (Byrd Field), VA (RIC/KRIC)',
#  'Montevideo-Carrasco Airport (MVD/SUMU)',
#  'Madinah-Mohammad Bin Abdulaziz Airport (MED/OEMA)',
#  'Sosnovo-Ozerskoe airfield (UIUS)',
#  'Santo Domingo-Herrera International Airport (HEX/MDHE)',
#  'Medford-Rogue Valley International, OR (MFR/KMFR)',
#  'Diyarbakir Airport (DIY/LTCC)',
#  'Gorontalo-Jalaluddin Airport (GTO/WAMG)',
#  'Eden Lake, BC',
#  'Chachapoyas Airport (CHH/SPPY)',
#  'Pattaya Airport (PYX/YTBF)',
#  'Honolulu-Daniel K. Inouye International Airport, HI (HNL/PHNL)',
#  'Santa Cruz-El Trompillo Airport (SRZ/SLET)',
#  'Douala Airport (DLA/FKKD)',
#  'TulcÃ¡n Airport (TUA/SETU)',
#  'Melilla Airport (MLN/GEML)',
#  "St. John's Airport, NL (YYT/CYYT)",
#  'Algiers-Houari Boumediene Airport (ALG/DAAG)',
#  'Buenos Aires-Jorge Newbery Airport, BA (AEP/SABE)',
#  'San Angelo-Ducote Airpark, TX',
#  'Chengdu Airport (CTU/ZUUU)',
#  'Nairobi (unknown airport)',
#  'Rio Branco-PlÃ¡cido de Castro International Airport, AC (RBR/SBRB)',
#  'Aberdeen-Dyce Airport (ABZ/EGPD)',
#  'Poplar Hill Airport, ON (YHP)',
#  'Baucau-English Madeira Airport (BCH/WPEC)',
#  'Fuzhou Changle International Airport (FOC/ZSFZ)',
#  'Helsinki-Vantaa Airport (HEL/EFHK)',
#  'Florencia Airport (FLA/SKFL)',
#  'Brasschaat Air Base (EBBT)',
#  'Kerman Airport (KER/OIKK)',
#  'Kohat Airport (OHT/OPKT)',
#  'Blenheim-Woodbourne Airport (BHE/NZWB)',
#  'Borki Airport',
#  'Kotzebue Airport, AK (OTZ/PAOT)',
#  'Cottage Grove State Airport, OR',
#  'Rimini-Miramare Airport (RMI/LIPR)',
#  'GhardaÃ¯a-NoumÃ©rat Airport (GHA/DAUG)',
#  'New Bern-Craven County Regional Airport, NC (EWN/KEWN)',
#  'Rumbek Airport (RBX/HSMK)',
#  'Cherry Point MCAS, NC (KNKT)',
#  'Hailey-Friedman Memorial Airport, ID (SUN/KSUN)',
#  'Accra-Kotoka Airport (ACC/DGAA)',
#  'Badiraguato Airport',
#  'Tainan Airport (TNN/RCNN)',
#  'Santos Air Base, SP (SSZ/SBST)',
#  'Larandia Air Base',
#  'Flushing, NY (LGA)',
#  'Oujda-Les Angades Airport (OUD/GMFO)',
#  'Ankara-Esenboga Airport (ESB/LTAC)',
#  'Fitchburg Municipal Airport, MA (FIT/KFIT)',
#  'ZÃ¼rich-Kloten Airport (ZRH/LSZH)',
#  'Toledo-Express Airport, OH (TOL/KTOL)',
#  'Saint Louis-Lambert International Airport, MO (STL/KSTL)',
#  'Dubois-Jefferson County Airport, PA (DUJ/KDUJ)',
#  'Sredny Island',
#  'Chetumal Airport (CTM/MMCM)',
#  'Prince Albert Airport, SK (YPA/CYPA)',
#  'Cincinnati Municipal Airport, OH (LUK/KLUK)',
#  'Roanoke-Blacksburg Regional Airport, VA (ROA/KROA)',
#  'Thunder Bay Airport, ON (YQT/CYQT)',
#  'Tokunoshima Airport (TKN/RJKN)',
#  'Cairo International Airport (CAI/HECA)',
#  'Strasbourg-Entzheim Airport (SXB/LFST)',
#  'Tashkent Airport (TAS/UTTT)',
#  'Windsor Airport, ON (YQG/CYQG)',
#  'Mulia Airport (LII/WABQ)',
#  'Pescara-Liberi Airport (PSR/LIBP)',
#  'Pueblo Memorial Airport, CO (PUB/KPUB)',
#  'Milano-Malpensa Airport (MXP/LIMC)',
#  'Akron/Canton Regional Airport, OH (CAK/KCAK)',
#  'Newtok Airport, AK (WWT/PAEW)',
#  'Cataratas del IguazÃº Airport, MI (IGR/SARI)',
#  'Cardiff-Wales Airport (CWL/EGFF)',
#  'Muskegon Airport, MI (MKG/KMKG)',
#  'Cagliari-Elmas Airport (CAG/LIEE)',
#  'Edmonton International Airport, AB (YEG/CYEG)',
#  'Mostar Airport (OMO/LQMO)',
#  'Quetta Airport (UET/OPQT)',
#  'Subic Bay International Airport (SFS/RPLB)',
#  'Guayaquil-Simon Bolivar Airport (GYE/SEGU)',
#  'Narathiwat Airport (NAW/VTSC)',
#  'Marseille-Provence Airport (MRS/LFML)',
#  'San Diego-Miramar NAS, CA (NKX/KNKX)',
#  'Catania-Fontanarossa Airport (CTA/LICC)',
#  'Manhattan, KS (MHK)',
#  'Tonopah-Test Range Airport, NV (XSD/KTNX)',
#  'KleinÂ\x92s Camp Airstrip',
#  'Utica-Oneida County Airport, NY (UCA/KUCA)',
#  'Placencia Airport (PLJ)',
#  'Windsor Locks-Bradley International Airport, CT (BDL/KBDL)',
#  'Oostende Airport (OST/EBOS)',
#  'Shabunda Airport (FZMW)',
#  'Puerto Esperanza Airport (SPEP)',
#  'Blackbushe Airport (BBS/EGLK)',
#  'Norfolk NAS Chambers, VA (NGU/KNGU)',
#  'Belize City-Philip S.W. Goldson International Airport (BZE/MZBZ)',
#  'Daytona Beach-Spruce Creek Airport, FL',
#  'Islip-Long Island MacArthur Airport, NY (ISP/KISP)',
#  'Papeete-Faaa Airport (PPT/NTAA)',
#  'Doha International Airport (DOH/OTBD)',
#  'Wilmington-New Hanover County Airport, NC (ILM/KILM)',
#  'Chibougamau/Chapais Airport, QC (YMT/CYMT)',
#  'Trieste-Ronchi dei Legionari Airport (TRS/LIPQ)',
#  'Kiev-Zhulhyany Airport (IEV/UKKK)',
#  'Porto Alegre-Salgado Filho International Airport, RS (POA/SBPA)',
#  'Memphis International Airport, TN (MEM/KMEM)',
#  'Uonquen Airport (SVUQ)',
#  'Carepa-Antonio RoldÃ¡n Betancourt Airport (SKLC)',
#  'Fort de France-Lamentin Air Base (BA 365) (FDF/TFFF)',
#  'Ayod Airstrip',
#  'Fairbanks International Airport, AK (FAI/PAFA)',
#  'El Obeid Airport (EBD/HSOB)',
#  'Phinda Aerodrome. (Game Lodge near Richards Bay)',
#  'King Salmon Airport, AK (AKN/PAKN)',
#  'Dhaalu Atoll',
#  'Baku-Heydar Aliyev International Airport (GYD/UBBB)',
#  'Lukla Airport (LUA/VNLK)',
#  'Las Vegas-North Air Terminal, NV (VGT/KVGT)',
#  'Msembe Ruaha National Park (HTMR)',
#  'Florence-Peretola Airport (FLR/LIRQ)',
#  'Ainsworth Airport, NE (ANW/KANW)',
#  'Banda Aceh-Blang Bintang Airport (BTJ/WITT)',
#  'Goa-Dabolim Airport (GOI/VAGO)',
#  'Andahuaylas Airport (ANS/SPHY)',
#  'Gunnison-Crested Butte Regional Airport, CO (GUC/KGUC)',
#  'Cali-Alfonso Bonilla AragÃ³n Airport (CLO/SKCL)',
#  'Kinshasa (unknown airport)',
#  'Logan-Cache Airport, UT (LGU/KLGU)',
#  'ChitrÃ© Airport (CTD/MPCE)',
#  'Tura (UNIT)',
#  'Manchester Municipal Airport, NH (MHT/KMHT)',
#  'Lake Johnston Airport, WA (YLJN)',
#  'Sucre Airport (SRE/SLSU)',
#  'Oviedo/Aviles-Asturias Airport (OVD/LEAS)',
#  'DÃ¼sseldorf Airport (DUS/EDDL)',
#  'Rothera Research Station (EGAR)',
#  'Toksook Bay Airport, AK (OOK/PAOO)',
#  'Iasi Airport (IAS/LRIA)',
#  'Kansas City International Airport, MO (MCI/KMCI)',
#  'FlorÃ¸ Airport (FRO/ENFL)',
#  'Ã\x96rebro-Bofors Airport (ORB/ESOE)',
#  'Kabul International Airport (KBL/OAKB)',
#  'Tambacounda Airport (TUD/GOTT)',
#  'Rio Sidra Airport (RSI)',
#  'Aruba-Reina Beatrix Airport (AUA/TNCA)',
#  'Bromont Airport, QC (ZBM/CZBM)',
#  'Cochabamba-J Wilsterman Airport (CBB/SLCB)',
#  'Sarmi Airport (ZRM/WAJI)',
#  'Wobagen Airstrip',
#  'Enarotali Airport (EWI/WABT)',
#  'Colima Airport (CLQ/MMIA)',
#  'Las Vegas-McCarran International Airport, NV (LAS/KLAS)',
#  'Teterboro Airport, NJ (TEB/KTEB)',
#  'San Pedro Airport (SPR/MZSP)',
#  'Andoas-Alferez FAP Alfredo Vladimir Sara Bauer Airport (AOP/SPAS)',
#  'Campbeltown-Machrihanish Airport (CAL/EGEC)',
#  'Bedford-Hanscom Field, MA (BED/KBED)',
#  'Varandey Airport (VRI/ULDW)',
#  'Roma-Ciampino Airport (CIA/LIRA)',
#  'Portage La Prarie Airport, MB (YPG/CYPG)',
#  'Entebbe Airport (EBB/HUEN)',
#  'San Andres Island-Gustavo Rojas Pinilla Airport (ADZ/SKSP)',
#  'PapelÃ³n',
#  'Itaituba-Fazenda Vera Paz Airport, PA (SIJZ)',
#  'Miami-Dade Collier Airport, FL (TNT/KTNT)',
#  'Tirana-Rinas Airport (TIA/LATI)',
#  'Coca Airport (OCC/SECO)',
#  'Lima-Jorge ChÃ¡vez International Airport (LIM/SPIM)',
#  'Chico Airport, CA (CIC/KCIC)',
#  'Savusavu Airport (SVU/NFNS)',
#  'DeLand Municipal Airport, FL (KDED)',
#  'Hammerfest Airport (HFT/ENHF)',
#  'Isiro-Matari Airport (IRP/FZJH)',
#  'San Andros Airport (SAQ/MYAN)',
#  'Lockhart River Airport, QLD (IRG/YLHR)',
#  'Mesquite Airport, NV (MFH)',
#  'San Antonio International Airport, TX (SAT/KSAT)',
#  '(KHST)',
#  'Abuja International Airport (ABV/DNAA)',
#  'Cafunfo Airport (CFF/FNCF)',
#  'Inuvik, NT',
#  'Penang International Airport (PEN/WMKP)',
#  'Dresden Airport (DRS/EDDC)',
#  '(KLAS)',
#  'Marsa el-Brega Airport (LMQ/HLMB)',
#  'Trinidad Airport (TDD/SLTR)',
#  'Tortuquero Airport (TTQ/MRAO)',
#  'Oslo',
#  'JEFFERSONVILLE , IN (KJVY)',
#  'Almeria Airport (LEI/LEAM)',
#  '(KFYV)',
#  'Lagos-Murtala Muhammed International Airport (LOS/DNMM)',
#  'EirunepÃ© Airport, AM (ERN/SWEI)',
#  'San Francisco International Airport, CA (SFO/KSFO)',
#  'Hahn (HHN)',
#  'Hamadan Air Base (OIHS)',
#  'Filitheyo Seaplane Base',
#  'Washington, DC (DCA',
#  'Mazar-I-Sharif Airport (MZR/OAMS)',
#  'Manzini-Matsapha International Airport (MTS/FDMS)',
#  'Aeropuerto Internacional de Salta',
#  'SABE',
#  'MSLP',
#  'Fresno, CA (KFAT)',
#  '(KESC)',
#  'Sapporo-Okadama Airport (OKD/RJCO)',
#  'Hugo, OK (KHHW)',
#  'Darwin Airport, NT',
#  'CÃºcuta-Camilo Daza Airport (CUC/SKCC)',
#  'New York-John F. Kennedy International Airport, NY (JFK)',
#  'Lusaka International Airport (LUN/FLKK)',
#  'Aniak, AK (PANI)',
#  'Burbank/Glendale/Pasadena Airport, CA (BUR/KBUR)',
#  'Kiev-Borispol Airport (KBP/UKBB)',
#  'Greenville, SC (KGSP)',
#  '(KJAC)',
#  'Kuala Lumpur International Airport (KUL/WMKK)',
#  'Hyannis-Barnstable Airport, MA (HYA/KHYA)',
#  'Jos Airport (JOS/DNJO)',
#  'Ennadai Lake Airport, NU (CWJC)',
#  'Puerto Obaldia Airport (PUE/MPOA)',
#  '(KMIA)',
#  'London Heathrow Airport (LHR/EGLL)',
#  'AQP',
#  'Killeen Municipal Airport, TX (ILE/KILE)',
#  'Fox Harbour Airport, NS',
#  'Zaragoza Airport (ZAZ/LEZG)',
#  'MontrÃ©alâ\x80\x93Dorval International Airport, QC (YUL)',
#  'Rutherford Ranch, TX',
#  'Anuradhapura Airport (ACJ/VCCA)',
#  'San Fernando Airport, BA (SADF)',
#  'Johannesburg, South Africa (JNB/FAOR)',
#  'Las Vegas-McCarran  International Airport, NV (LAS/KLAS)',
#  'Marianna Municipal Airport, FL (KMAI)',
#  'CÃ³rdoba Airport, CD',
#  'Guayaquil-Simon Bolivar International Airport',
#  'Kigali International Airport (KGL/HRYR)',
#  'Davao City-Francisco Bangoy International Airport (DVO/RPMD)',
#  'Siirt Airport (SXZ/LTCL)',
#  'Zhengzhou Air Base',
#  'Dundo Airport (DUE/FNDU)',
#  'Mahdia Airport (MHA/SYMD)',
#  'Luanda Airport (LAD/FNLU)',
#  'Jayapura-Sentani Airport (DJJ/WAJJ)',
#  'Cincinnati/Northern Kentucky Airport, KY (CVG/KCVG)',
#  'Fort Worth-Meacham Field, TX (FTW/KFTW)',
#  'Troy Municipal Airport, AL (TOI/KTOI)',
#  'Taiz-Al Janad Airport (TAI/ODTZ)',
#  'Maiduguri Airport (MIU/DNMA)',
#  'Anchorage International Airport, AK (ANC/PANC)',
#  'Porlamar Airport (PMV/SVMG)',
#  'Stillwater Regional Airport, OK (SWO/KSWO)',
#  'Abu Dhabi International Airport (AUH/OMAA)',
#  'Tokyo-Narita Airport (NRT)',
#  'Okinawa-Naha Airport (OKA)',
#  'Donlin Creek Airstrip, AK',
#  'MitÃº Airport (MVP/SKMU)',
#  'Luena Airport (LUO/FNUE)',
#  'Pittsburgh International Airport, PA (PIT/KPIT)',
#  'New Orleans-Lakefront Airport, LA (NEW/KNEW)',
#  'Sheffield City Airport (SZD/EGSY)',
#  'Fort Pierce-Treasure Coast International Airport, FL (FPR/KFPR)',
#  'Pinedale-Ralph Wenz Field, WY (PWY/KPNA)',
#  'Bilbao Airport (BIO/LEBB)',
#  'Beaver Island Airport, MI (KSJX)',
#  'Jacobkondre',
#  'Punta Gorda-Charlotte County Airport, FL (PGD/KPGD)',
#  'Birnin Kebbi Airstrip',
#  'Berlin-Tempelhof Airport (THF/EDDI)',
#  'Monterey Regional Airport, CA (MRY/KMRY)',
#  'Sault Ste Marie, MI',
#  'Belfast International Airport (BFS/EGAA)',
#  'Chiang Mai International Airport (CNX/VTCC)',
#  'Oceana NAS, VA (NTU/KNTU)',
#  'Portland International Airport, OR (PDX/KPDX)',
#  'Hamburg-FuhlsbÃ¼ttel Airport (HAM/EDDH)',
#  'Bridgeport-Igor I. Sikorsky Memorial Airport, CT (BDR/KBDR)',
#  'Pohnpei Airport (PNI/PTPN)',
#  'Moskva (unknown airport)',
#  'Albany-Dougherty County Airport, GA (ABY/KABY)',
#  'Lubango Airport (SDD/FNUB)',
#  'Monrovia-Roberts International Airport (ROB/GLRB)',
#  'Saint-BarthÃ©lÃ©my Airport (SBH/TFFJ)',
#  'NÃ¼rnberg Airport (NUE/EDDN)',
#  'Decatur-Bishop Airfield, TX',
#  'Fort Myers-Southwest Florida Regional Airport, FL (RSW/KRSW)',
#  'Barinas Airport (BNS/SVBI)',
#  'Grande Prairie Airport, AB (YQU/CYQU)',
#  'Nouakchott Airport (NKC/GQNN)',
#  'Norfolk International Airport, VA (ORF/KORF)',
#  'Jacksonville International Airport, FL (JAX/KJAX)',
#  'Madeira-Funchal International Airport (FNC/LPFU)',
#  'Sangar',
#  'Albany Airport, NY (ALB/KALB)',
#  'Bangor International Airport, ME (BGR/KBGR)',
#  'Birmingham-Shuttlesworth International Airport, AL (BHM/KBHM)',
#  'Shamsi',
#  'Bucaramanga-Palo Negro Airport (BGA/SKBG)',
#  'Novosibirsk-Tolmachevo Airport (OVB/UNNN)',
#  'Chilpancingo Airport (MMCH)',
#  'Lago Agrio Airport (LGQ/SELA)',
#  'Atlanta-William B. Hartsfield International Airport, GA (ATL/KATL)',
#  'Hakodate Airport (HKD/RJCH)',
#  'Kavak Airstrip',
#  'Rapid City-Ellsworth AFB, SD (RCA/KRCA)',
#  'Camden-Harrell Field, AR (CDH/KCDH)',
#  'Novato Airport, CA (NOT/KDVO)',
#  'Broomfield-Rocky Mountain Metropolitan Airport, CO (BJC/KBJC)',
#  'Cleveland-Cuyahoga County Airport, OH (CGF/KCGF)',
#  'Blantyre-Chileka Airport (BLZ/FWCL)',
#  'Khorramabad Airport (KHD/OICK)',
#  'Vientiane-Wattay Airport (VTE/VLVT)',
#  'Lakhta Air Base',
#  'Tununak, AK (4KA)',
#  'London Stansted Airport (STN/EGS)',
#  'Bangkok-Don Muang International Airport (BKK/VTBD)',
#  'Goose Bay Airport, NL (YYR/CYYR)',
#  'Mozdok Air Base',
#  'Barrow, AK',
#  'Nashville Metropolitan Airport, TN (BNA/KBNA)',
#  'Tunis-Carthage Airport (TUN/DTTA)',
#  'Cayo Coco/Jardines del Rey Airport (CCC/MUCC)',
#  'Bolton Lake Airstrip, MB',
#  'Detroit-Willow Run Airport, MI (YIP/KYIP)',
#  'Belo Horizonte-Tancredo Neves International Airport, MG (CNF/SBCF)',
#  'Anderson Municipal Airport, IN (AID/KAID)',
#  'Seattle-Boeing Field International Airport, WA (BFI/KBFI)',
#  'LGW',
#  'Tervel Airstrip',
#  'Milan (MXP)',
#  'Weston-on-the-Green RAF Station',
#  'Busan-Gimhae (Pusan) International Airport (PUS/RKPK)',
#  'Reno/Tahoe International Airport, NV (RNO/KRNO)',
#  'Sun City-Pilanesberg Airport (NTY/FAPN)',
#  'Shenyang Airport (SHE/ZYTK)',
#  'Svalenik Airstrip',
#  'MedellÃ\xadn-Enrique Olaya Herrera Airport (EOH/SKMD)',
#  'LAKE IN THE HIL, IL (3CK)',
#  'New Bedford Airport, MA (EWB/KEWB)',
#  'Diamantina-Juscelino Kubitschek Airport, MG (DTI/SNDT)',
#  'Boise Air Terminal, ID (BOI/KBOI)',
#  'Pontianak-Supadio Airport (PNK/WIOO)',
#  'Mombasa-Moi International Airport (MBA/HKMO)',
#  'Beirut-Rafic Hariri International Airport (BEY/OLBA)',
#  'London Southend Airport (SEN/EGMC)',
#  'Exeter Airport (EXT/EGTE)',
#  'QuerÃ©taro Intercontinental Airport (QRO/MMQT)',
#  'Mukinge Mission Airstrip (FLGE)',
#  'Davenport Airport, IA (DVN/KDVN)',
#  'Taechon Air Base',
#  'Paris-Le Bourget Airport (LBG/LFPB)',
#  'Burevestnik Airport (BVV/UHSB)',
#  'Kona-Keahole Airport, HI (KOA/PHKO)',
#  'MalÃ©-Velana International Airport (MLE/VRMM)',
#  'Blois/Le Breuil Airfield (LFOQ)',
#  'Jeffersonville-Clark Regional Airport, IN (JVY/KJVY)',
#  'Vijayawada Airport (VGA/VOBZ)',
#  'Gillam Airport, MB (YGX/CYGX)',
#  'Villahermosa-Carlos Rovirosa PÃ©rez International Airport (VSA/MMVA)',
#  'Minna Airport (MXJ/DNMN)',
#  'Kegen Airstrip',
#  'Monfort Airport (MFB)',
#  'Ganzhou Airport (KOW/ZSGZ)',
#  'Yuai Airstrip',
#  'Mashhad-Shahid Hashemi Nejad Airport (MHD/OIMM)',
#  'Angguruk Airstrip',
#  'Almaty Airport (ALA/UAAA)',
#  'Fort Worth, TX',
#  'Los Angeles, CA',
#  'Nairobi-Wilson Airport (WIL/HKNW)',
#  'Galena Airport, AK (GAL/PAGA)',
#  'Charleston AFB, SC (CHS/KCHS)',
#  'Colorado Springs Municipal Airport, CO (COS/KCOS)',
#  'Chignik-Lagoon Airport, AK (KCL)',
#  'Toluca-Licenciado Adolfo LÃ³pez Mateos International Airport (TLC/MMTO)',
#  'Columbia Metropolitan Airport, SC (CAE/KCAE)',
#  'Ridgeland Airport, SC',
#  'Gwalior Airport (GWL/VIGR)',
#  'Nangang Island-Matsu Nangan Airport (LZN/RCFG)',
#  'Alicante Airport (ALC/LEAL)',
#  'Denver-Centennial Airport, CO (APA/KAPA)',
#  'Melipilla-Los Cuatro Diablos Airport (SCME)',
#  'Laytamak Airstrip',
#  'Kaduna Airport (KAD/DNKA)',
#  'Jeju (Cheju) International Airport (CJU/RKPC)',
#  'Palm Beach-Palm Beach County Airport, FL (LNA/KLNA)',
#  'Athens-ElefthÃ©rios VenizÃ©los International Airport (ATH/LGAV)',
#  'Atlanta-Cobb County-Mc Collum Field, GA (KRYY)',
#  'Wiener Neustadt West AB (LOXN)',
#  'Kolkata-Netaji Subhas Chandra Bose International Airport (CCU/VECC)',
#  'Anisakan (VYAS)',
#  'MÃ¡laga-Costa del Sol Airport (AGP/LEMG)',
#  'Hubli Airport (HBX/VOHB)',
#  'Tanay Airfield',
#  'GenÃ¨ve-Cointrin Airport (GVA/LSGG)',
#  'Teuge Airport (EHTE)',
#  'Penticton Airport, BC (YYF/CYYF)',
#  'Kahului Airport, HI (OGG/PHOG)',
#  'Jolo Airport (JOL/RPMJ)',
#  'Savonlinna Airport (SVL/EFSA)',
#  'Uvalde-Ox Ranch Airport ,TX',
#  'Payam International Airport (PYK/OIIP)',
#  'Imbaimadai Airport (IMB/SYIB)',
#  'Wellington International Airport (WLG/NZWN)',
#  'Moskva-Sheremetyevo Airport (SVO/UUEE)',
#  'Montreal-Pierre Elliott Trudeau International Airport, QC (YUL/CYUL)',
#  'Buffalo-Greater Buffalo International Airport, NY (BUF/KBUF)',
#  'Tuscaloosa Regional Airport, AL (TCL/KTCL)',
#  'Kake Airport, AK (PAFE)',
#  'WhatÃ¬/Lac La Martre Airport, NT (YLE)',
#  'Chengdu Shuangliu International Airport (ZUUU)',
#  'Miami-Opa locka Executive Airport, FL (OPF/KOPF)',
#  'Richmond Municipal Airport, IN (RID/KRID)',
#  'Saint-BarthÃ©lÃ©my-RÃ©my de Haenen Airport (SBH/TFFJ)',
#  'Chittagong-Shah Amanat International Airport (CGP/VGEG)',
#  'Pyongtaek-Desiderio AAF (RKSG)',
#  'Southampton-Eastleigh Airport (SOU/EGHI)',
#  'Ouargla-Ain Beida Airport (OGX/DAUU)',
#  'Little Grand Rapids Airport, MB (ZGR/CZGR)',
#  'Atlanta-DeKalb Peachtree Airport, GA (PDK/KPDK)',
#  'Villavicencio Airport (VVC/SKVV)',
#  'Nashville International Airport, TN (BNA/KBNA)',
#  'Augusta-Bush Field, GA (AGS/KAGS)',
#  'Monongahela-Rostraver Airport, PA (KFWQ)',
#  'Orlando Sanford International Airport, FL (SFB/KSFB)',
#  'Oklahoma City-Sundance Airpark, OK (HSD/KHSD)',
#  'Kuala Lumpur-Sultan Abdul Aziz Shah Airport (SZB/WMSA)',
#  'SÃ£o TomÃ© Island Airport (TMS/FPST)',
#  'Katowice-Pyrzowice Airport (KTW/EPKT)',
#  'MÃ¡laga Airport (AGP/LEMG)',
#  'Innsbruck-Kranebitten Airport (INN/LOWI)',
#  'Dominica Douglas-Charles Airport (DOM/TDPD)',
#  'Fort Myers, FL',
#  'Hamilton-Marion County Airport, AL (HAB/KHAB)',
#  'Ramechhap Airport (RHP/VNRC)',
#  'KÃ¶ln/Bonn-Konrad Adenauer Airport (CGN/EDDK)',
#  'Ayacara Airport (SCAY)',
#  'Khon Kaen Airport (KKC/VTUK)',
#  'Key West International Airport, FL (EYW/KEYW)',
#  'Churchill Airport, MB (YYQ/CYYQ)',
#  'Siegen-Siegerland Airport (SGE/EDGS)',
#  'East Midlands Airport (EMA/EGNX)',
#  'Jacksonville NAS, FL (NIP/KNIP)',
#  'KeflavÃ\xadk International Airport (KEF/BIKF)',
#  'Murmansk Airport (MMK/ULMM)',
#  'Uriman Airport (URM/SVUM)',
#  'Kuujjuarapik Airport, QC (YGW/CYGW)',
#  'Yangon-Mingaladon Airport (RGN/VYYY)',
#  'Sudbury Airport, ON (YSB/CYSB)',
#  'Saint-Esprit Aerodrome, QC',
#  'Mandalay International Airport (MDL/VYMD)',
#  'Ketchikan Harbor Seaplane Base, AK (WFB)',
#  'Minden-Tahoe Airport, NV (MEV/KMEV)',
#  'Comodoro Rivadavia Airport, CB (CRD/SAVC)',
#  'Lansing-Capital City Airport, MI (LAN/KLAN)',
#  'Bloemspruit Air Force Base (BFN/FABL)',
#  'Terra Nova Bay-Zucchelli Station',
#  'Boituva-Centro Nacional de PÃ¡raquedismo Airfield, SP (SDOI)',
#  'Okiwi Station (NZOX)',
#  'Roma-Fiumicino Airport (FCO/LIRF)',
#  'Poltava Airport (PLV/UKHP)',
#  'Blue River Airport, BC (CYCP)',
#  'Muscat International Airport (MCT/OOMS)',
#  'Donetsk Airport (DOK/UKCC)',
#  'Tianjin Airport (TSN/ZBTJ)',
#  'Raleigh-Durham, NC',
#  'Thomson-McDuffie County Airport, GA (KHQU)',
#  'Tunica Municipal Airport, MS (UTM/KUTA)',
#  'Wau Airport (WUU/HSWW)',
#  'Ponta Delgada-JoÃ£o Paulo II Airport, Azores (PDL/LPPD)',
#  'Rybinsk Airport (RYB/UUBK)',
#  'Pias Airport (SPIS)',
#  'Dillingham Municipal Airport, AK (DLG/PADL)',
#  'South Bend Regional, IN (SBN/KSBN)',
#  "Kinshasa-N'Dolo Airport (NLO/FZAB)",
#  'Las Palmas',
#  'St. Anthony Airport, NL (YAY/CYAY)',
#  'Lyon Saint-ExupÃ©ry Airfield (LYS/LFLL)',
#  'Walaha Airport (WLH/NVSW)',
#  'Padang-Minangkabau International Airport (PDG/WIEE)',
#  'Glasgow-Prestwick Airport (PIK/EGPK)',
#  'Denpasar-Ngurah Rai Bali International Airport (DPS/WADD)',
#  'Mexico City-Benito JuÃ¡rez International Airport (MEX/MMMX)',
#  'Dubai World Central-Al Maktoum International Airport (DWC/OMDW)',
#  'Oslo-Gardermoen Airport (OSL/ENGM)',
#  'Grise Fiord Airport, NU (YGZ/CYGZ)',
#  'Valencia-Arturo Michelena International Airport (VLN/SVVA)',
#  'Gebe Airport (GEB/WAMJ)',
#  'McMinnville Municipal Airport, OR (KMMV)',
#  'Mong Hsat Airport (MOG/VYMS)',
#  'Jomsom Airport (JMO/VNJS)',
#  'Shenyang-Taoxian International Airport (SHE/ZYTX)',
#  'Shank Forward Operating Base (OAA)',
#  'Varna Airport (VAR/LBWN)',
#  'Tash Kumyr Airstrip',
#  ...]

# %%
import re

def extract_iata(airport_str):
    """Extracts the 3-letter IATA code from airport strings."""
    if pd.isna(airport_str) or not isinstance(airport_str, str):
        return None
    
    match = re.search(r'\((\w{3})/\w{4}\)', airport_str)  # (IATA/ICAO)
    
    if match:
        return match.group(1)
    
    match_alt = re.search(r'\((\w{3})\)', airport_str)  # (IATA)
    
    if match_alt:
        return match_alt.group(1)
    
    return None 

df["Departure_airport_IATA"] = df["Departure_airport"].apply(extract_iata)
df["Destination_airport_IATA"] = df["Destination_airport"].apply(extract_iata)

# %%
df[
    df["Departure_airport_IATA"].isna() & 
    df["Departure_airport"].notna() & 
    (df["Departure_airport"] != "-")
][["Departure_airport"]].sample(30)
# Out:
#                                       Departure_airport
# 5247                               Akobo Airport (HSAK)
# 2076                         Juba International Airport
# 3041                DeLand Municipal Airport, FL (KDED)
# 1920                 Spa-La SauveniÃ¨re Airfield (EBSP)
# 114   Maputo International Aerodrome (FQMA) in Mozam...
# 742                         MedellÃ­n (unknown airport)
# 6561                            Jacksonville, FL (KJAX)
# 2120                 Spa-La SauveniÃ¨re Airfield (EBSP)
# 3838  Caracas/La Carlota-Gen. Francisco de Miranda A...
# 7720                  Pamiers/Les Pujols Airport (LFDJ)
# 2479                                        Kilimanjaro
# 1033                              Intuto Airport (SPNT)
# 6138    Richmond-Chesterfield County Airport, VA (KFCI)
# 1099                              Ciudad del Este - AGT
# 1326                                   Miami, FL (KOPF)
# 930                            Novolazarevskaya Station
# 4289                                     Pieri Airstrip
# 3532                        Decatur-Bishop Airfield, TX
# 1758                      Tequesquitengo Airport (MMTQ)
# 1995                         Verona/Boscomantico (LIPN)
# 6661                            Jacksonville, FL (KJAX)
# 4964                  South Pole-Amundsen-Scott Station
# 2640                                    Ganes Creek, AK
# 2565                            Pelee Island, ON (CYPT)
# 1958  Bentonville Municipal-Louise M Thaden Field, A...
# 3382                                        , MA (KBOS)
# 5219                               Fentress Airpark, TX
# 7208                               Goa-INS Hansa (VOGO)
# 6130                           Boufarik Air Base (DAAK)
# 1927                   Sosnovo-Ozerskoe airfield (UIUS)

# %%
def extract_icao(airport_str):
    """Extracts the 4-letter ICAO code from airport strings if no IATA is found."""
    if pd.isna(airport_str) or not isinstance(airport_str, str) or airport_str == "-":
        return None  # Handle missing values
    
    match = re.search(r'\((\w{3})/(\w{4})\)', airport_str)  # (IATA/ICAO)
    if match:
        return match.group(2)
    
    match_alt = re.search(r'\((\w{4})\)', airport_str)  # (ICAO)
    if match_alt:
        return match_alt.group(1)
    
    return None

df["Departure_airport_ICAO"] = df.apply(
    lambda row: extract_icao(row["Departure_airport"]) if pd.isna(row["Departure_airport_IATA"]) else None, axis=1
)
df["Destination_airport_ICAO"] = df.apply(
    lambda row: extract_icao(row["Destination_airport"]) if pd.isna(row["Destination_airport_IATA"]) else None, axis=1
)

# %%
df[df["Departure_airport_IATA"].isna() 
   & df["Departure_airport_ICAO"].isna() 
   & df["Departure_airport"].notna() & (df["Departure_airport"] != "-")]['Departure_airport'].value_counts().reset_index()['Departure_airport'].unique()
# Out:
# array(['SABE', 'Sebastian Municipal Airport, FL', 'Tanay Airfield',
#        'Pieri Airstrip', 'Inuvik, NT', 'Decatur-Bishop Airfield, TX',
#        'Abuja', 'Ronald Reagan, DC (DCA', 'Ankara (unknown airport)',
#        'Quito', 'DELTA JUNCTION , AK (D66', 'Estancia Las Cruces, ER',
#        'Moncton', 'Dili', 'LBGO', 'Columbus, OH ( CMH)', 'AEP',
#        'Piajo Airstrip', 'Perryville Municipal Airport, MO',
#        'Manning Airport, AB', 'Fentress Airpark, TX',
#        'Tayoltita Airstrip', 'Sterlitamark Airfield',
#        'Cookstown Airport, ON', 'Tash Kumyr Airstrip', 'Hamburg',
#        'Djolu Airport', 'South Pole-Amundsen-Scott Station', 'SAEZ',
#        'Rudyerd Bay, AK', 'Tianjin International Airport',
#        'Saint-Esprit Aerodrome, QC', 'Kidron-Stoltzfus Airfield, OH',
#        'Gods Lake Narrows, Manitoba',
#        'Hamilton-Ravalli County Airport, MT', 'Kaskattama Airstrip, MB',
#        'COMO Maalifushi Resort', 'Taechon Air Base', 'Lodi Airport, CA',
#        'Kichwa Tembo Airstrip', 'Nairobi (unknown airport)',
#        'Lily Beach Resort, Huvahendhoo, Alif Dhaal Atoll',
#        'Ajongthok Airstrip', 'Kattleberg Airport', 'Azov Airfield',
#        'Caracas (unknown airport)', 'Jeddah', 'Tersky',
#        'Miyazaki Airport', 'Clayton County Airport-Tara Field, GA',
#        'Tharjath Airstrip', 'Sharara Airstrip', 'Kuajok Airstrip',
#        'Gardiner Airport, NY',
#        'Rio de Janeiro/GaleÃ£o-Antonio Carlos Jobim International Airport, RJ (GIG/SBG',
#        'Kuweires Air Base', 'Zhetygen Air Base', 'Dolow Airport',
#        'Rangali Island', 'Perris Valley Airport, CA',
#        'Five Point-Agro-West Airport, CA', 'Svalenik Airstrip',
#        'Mara Ngerende Airstrip', 'Weston-on-the-Green RAF Station',
#        'Tervel Airstrip', 'Saint Louis (unknown airport), MO',
#        'Sturt Island Airstrip', 'Larandia Air Base', 'Port de PollenÃ§a',
#        'Obuasi Airstrip', 'Marial Bal Airstrip',
#        'Creswell-Hobby Field Airport, OR', 'Borki Airport', 'Sauce Viejo',
#        'USDA', 'Juba International Airport', 'Kajjansi Airfield ?',
#        'Juba', 'Boston Logan International Airport', 'YRAY',
#        'Mayout airstrip', 'Mount Lymburner', 'Ust-Kara Airstrip',
#        'Ayers Rock, NT', 'Kilimanjaro', 'Kanantik Airstrip',
#        'Casablanca (unknown airport)', 'Bishkek District Airport',
#        'Elk Island Airport, MB', 'Walikale Airstrip',
#        'Â\x8aentvid pri Sticni Airfield',
#        'MedellÃ\xadn (unknown airport)', 'Kozlovets', 'Jiech',
#        'Novolazarevskaya Station', 'Medan', 'Dolinsk-Sokol Air Base',
#        'Ciudad del Este - AGT', 'Bagay-Baranovka Airport', 'Bozoy',
#        'Ganes Creek, AK', 'McGrath, AK', 'Ellington Airport, CT',
#        'Purari',
#        'Kalamazoo-Battle Creek International Airport, MI (AZO/AZO)',
#        'GPOC Unity Airstrip', 'Rottnest Island, WA'], dtype=object)

# %%
# %%script false --no-raise-error # execute when needed
# %pip install fuzzywuzzy

# %%
# manually clean departure airports
df[df["Departure_airport"].notna() & (df["Departure_airport"] != "-") & df["Departure_airport_IATA"].isna() & df["Departure_airport_ICAO"].isna()][['Departure_airport', 'Matched_Airport_Name']].Departure_airport.value_counts().reset_index()['Departure_airport']#[df.Matched_Airport_Name.isna()][['Departure_airport', 'Matched_Airport_Name']].Departure_airport.value_counts()
# Out:
# 0                                                   SABE
# 1                        Sebastian Municipal Airport, FL
# 2                                         Tanay Airfield
# 3                                         Pieri Airstrip
# 4                                             Inuvik, NT
# 5                            Decatur-Bishop Airfield, TX
# 6                                                  Abuja
# 7                                 Ronald Reagan, DC (DCA
# 8                               Ankara (unknown airport)
# 9                                                  Quito
# 10                              DELTA JUNCTION , AK (D66
# 11                               Estancia Las Cruces, ER
# 12                                               Moncton
# 13                                                  Dili
# 14                                                  LBGO
# 15                                   Columbus, OH ( CMH)
# 16                                                   AEP
# 17                                        Piajo Airstrip
# 18                      Perryville Municipal Airport, MO
# 19                                   Manning Airport, AB
# 20                                  Fentress Airpark, TX
# 21                                    Tayoltita Airstrip
# 22                                 Sterlitamark Airfield
# 23                                 Cookstown Airport, ON
# 24                                   Tash Kumyr Airstrip
# 25                                               Hamburg
# 26                                         Djolu Airport
# 27                     South Pole-Amundsen-Scott Station
# 28                                                  SAEZ
# 29                                       Rudyerd Bay, AK
# 30                         Tianjin International Airport
# 31                            Saint-Esprit Aerodrome, QC
# 32                         Kidron-Stoltzfus Airfield, OH
# 33                           Gods Lake Narrows, Manitoba
# 34                   Hamilton-Ravalli County Airport, MT
# 35                               Kaskattama Airstrip, MB
# 36                                COMO Maalifushi Resort
# 37                                      Taechon Air Base
# 38                                      Lodi Airport, CA
# 39                                 Kichwa Tembo Airstrip
# 40                             Nairobi (unknown airport)
# 41      Lily Beach Resort, Huvahendhoo, Alif Dhaal Atoll
# 42                                    Ajongthok Airstrip
# 43                                    Kattleberg Airport
# 44                                         Azov Airfield
# 45                             Caracas (unknown airport)
# 46                                                Jeddah
# 47                                                Tersky
# 48                                      Miyazaki Airport
# 49                 Clayton County Airport-Tara Field, GA
# 50                                     Tharjath Airstrip
# 51                                      Sharara Airstrip
# 52                                       Kuajok Airstrip
# 53                                  Gardiner Airport, NY
# 54     Rio de Janeiro/GaleÃ£o-Antonio Carlos Jobim In...
# 55                                     Kuweires Air Base
# 56                                     Zhetygen Air Base
# 57                                         Dolow Airport
# 58                                        Rangali Island
# 59                             Perris Valley Airport, CA
# 60                      Five Point-Agro-West Airport, CA
# 61                                     Svalenik Airstrip
# 62                                Mara Ngerende Airstrip
# 63                       Weston-on-the-Green RAF Station
# 64                                       Tervel Airstrip
# 65                     Saint Louis (unknown airport), MO
# 66                                 Sturt Island Airstrip
# 67                                     Larandia Air Base
# 68                                     Port de PollenÃ§a
# 69                                       Obuasi Airstrip
# 70                                   Marial Bal Airstrip
# 71                      Creswell-Hobby Field Airport, OR
# 72                                         Borki Airport
# 73                                           Sauce Viejo
# 74                                                  USDA
# 75                            Juba International Airport
# 76                                   Kajjansi Airfield ?
# 77                                                  Juba
# 78                    Boston Logan International Airport
# 79                                                  YRAY
# 80                                       Mayout airstrip
# 81                                       Mount Lymburner
# 82                                     Ust-Kara Airstrip
# 83                                        Ayers Rock, NT
# 84                                           Kilimanjaro
# 85                                     Kanantik Airstrip
# 86                          Casablanca (unknown airport)
# 87                              Bishkek District Airport
# 88                                Elk Island Airport, MB
# 89                                     Walikale Airstrip
# 90                          Âentvid pri Sticni Airfield
# 91                           MedellÃ­n (unknown airport)
# 92                                             Kozlovets
# 93                                                 Jiech
# 94                              Novolazarevskaya Station
# 95                                                 Medan
# 96                                Dolinsk-Sokol Air Base
# 97                                 Ciudad del Este - AGT
# 98                               Bagay-Baranovka Airport
# 99                                                 Bozoy
# 100                                      Ganes Creek, AK
# 101                                          McGrath, AK
# 102                                Ellington Airport, CT
# 103                                               Purari
# 104    Kalamazoo-Battle Creek International Airport, ...
# 105                                  GPOC Unity Airstrip
# 106                                  Rottnest Island, WA
# Name: Departure_airport, dtype: object

# %% [markdown]
# 0                                                   SABE ("AEP", "SABE")
# 1                        Sebastian Municipal Airport, FL (None, None)
# 2                                         Tanay Airfield (None, "XNET")
# 3                                         Pieri Airstrip (None, "SS-0007")
# 4                                             Inuvik, NT ("YEV","CYEV")
# 5                            Decatur-Bishop Airfield, TX (None, None)
# 6                                                  Abuja ("ABV","DNAA")
# 7                                 Ronald Reagan, DC (DCA ("DCA","KDCA")
# 8                               Ankara (unknown airport) (None, None)
# 9                                                  Quito ("UIO","SEQM")
# 10                              DELTA JUNCTION , AK (D66 ("DJN", None)
# 11                               Estancia Las Cruces, ER ("LRU", "KLRU")
# 12                                               Moncton ("YQM", "CYQM")
# 13                                                  Dili (None, None)
# 14                                                  LBGO ("GOZ", "LBGO")
# 15                                   Columbus, OH ( CMH) ("CMH", "KCMH")
# 16                                                   AEP ("AEP", "SABE")
# 17                                        Piajo Airstrip ("POS", "TTPP")
# 18                      Perryville Municipal Airport, MO (None, "KPCD")
# 19                                   Manning Airport, AB (None, None)
# 20                                  Fentress Airpark, TX (None, None)
# 21                                    Tayoltita Airstrip (None, None)
# 22                                 Sterlitamark Airfield (None, None)
# 23                                 Cookstown Airport, ON (None, None)
# 24                                   Tash Kumyr Airstrip (None, None)
# 25                                               Hamburg ("HAM", "EDDH")
# 26                                         Djolu Airport (None, None)
# 27                     South Pole-Amundsen-Scott Station (None, "NZSP")
# 28                                                  SAEZ ("EZE", "SAEZ")
# 29                                       Rudyerd Bay, AK (None, None)
# 30                         Tianjin International Airport ("TSN", "ZBTJ")
# 31                            Saint-Esprit Aerodrome, QC (None, None)
# 32                         Kidron-Stoltzfus Airfield, OH (None, "OH22")
# 33                           Gods Lake Narrows, Manitoba ("YGO", "CYGO")
# 34                   Hamilton-Ravalli County Airport, MT (None, None)
# 35                               Kaskattama Airstrip, MB (None, None)
# 36                                COMO Maalifushi Resort (None, None)
# 37                                      Taechon Air Base (None, None)
# 38                                      Lodi Airport, CA ("1O3", None)
# 39                                 Kichwa Tembo Airstrip ("KTJ", None)
# 40                             Nairobi (unknown airport) (None, None)
# 41      Lily Beach Resort, Huvahendhoo, Alif Dhaal Atoll (None, None)
# 42                                    Ajongthok Airstrip (None, None)
# 43                                    Kattleberg Airport (None, None)
# 44                                         Azov Airfield (None, "RUAZ")
# 45                             Caracas (unknown airport) (None, None)
# 46                                                Jeddah ("JED", "OEJN")
# 47                                                Tersky ("TYS", "KTYS")
# 48                                      Miyazaki Airport ("KMI", "RJFM")
# 49                 Clayton County Airport-Tara Field, GA (None, "KHMP")
# 50                                     Tharjath Airstrip (None, None)
# 51                                      Sharara Airstrip ("OAS", "OASA")
# 52                                       Kuajok Airstrip (None, None)
# 53                                  Gardiner Airport, NY ("5NY5", "5NY5")
# 54     Rio de Janeiro/GaleÃ£o-Antonio Carlos Jobim In... ("GIG", "SBGL")
# 55                                     Kuweires Air Base (None, None)
# 56                                     Zhetygen Air Base (None, None)
# 57                                         Dolow Airport (None, None)
# 58                                        Rangali Island (None, None)
# 59                             Perris Valley Airport, CA (None, None)
# 60                      Five Point-Agro-West Airport, CA ("5CA7", None)
# 61                                     Svalenik Airstrip (None, None)
# 62                                Mara Ngerende Airstrip (None, None)
# 63                       Weston-on-the-Green RAF Station (None, None)
# 64                                       Tervel Airstrip (None, None)
# 65                     Saint Louis (unknown airport), MO (None, None)
# 66                                 Sturt Island Airstrip (None, "AYST")
# 67                                     Larandia Air Base (None, None)
# 68                                     Port de PollenÃ§a (None, "LEPO")
# 69                                       Obuasi Airstrip (None, None)
# 70                                   Marial Bal Airstrip (None, None)
# 71                      Creswell-Hobby Field Airport, OR (None, "K77S")
# 72                                         Borki Airport (None, None)
# 73                                           Sauce Viejo ("SFN", "SAAV")
# 74                                                  USDA ("SBT", "USDA")
# 75                            Juba International Airport ("JUB", "HJJJ")
# 76                                   Kajjansi Airfield ? ("KJJ", "HUKJ")
# 77                                                  Juba ("JUB", "HJJJ")
# 78                    Boston Logan International Airport ("BOS", "KBOS")
# 79                                                  YRAY (None, None)
# 80                                       Mayout airstrip (None, None)
# 81                                       Mount Lymburner (None, None)
# 82                                     Ust-Kara Airstrip (None, None)
# 83                                        Ayers Rock, NT ("AYQ", "YAYE")
# 84                                           Kilimanjaro ("JRO", "HTKJ")
# 85                                     Kanantik Airstrip ("SVK", "MZKT")
# 86                          Casablanca (unknown airport) (None, None)
# 87                              Bishkek District Airport (None, None)
# 88                                Elk Island Airport, MB (None, None)
# 89                                     Walikale Airstrip (None, None)
# 90                          Âentvid pri Sticni Airfield (None, None)
# 91                           MedellÃ­n (unknown airport) (None, None)
# 92                                             Kozlovets ("SVX", "USSS")
# 93                                                 Jiech (None, None)
# 94                              Novolazarevskaya Station ("QAO", "AT17")
# 95                                                 Medan ("KNO", "WIMM")
# 96                                Dolinsk-Sokol Air Base (None, "XHSO")
# 97                                 Ciudad del Este - AGT ("AGT", "SGES")
# 98                               Bagay-Baranovka Airport (None, None)
# 99                                                 Bozoy (None, None)
# 100                                      Ganes Creek, AK ("GEK", None)
# 101                                          McGrath, AK ("MCG", "PAMC")
# 102                                Ellington Airport, CT (None, None)
# 103                                               Purari (None, None)
# 104    Kalamazoo-Battle Creek International Airport, ... ("AZO", "KAZO")
# 105                                  GPOC Unity Airstrip (None, None)
# 106                                  Rottnest Island, WA ("RTS", "YRTI")
# Name: Departure_airport, dtype: object

# %% [markdown]
# **Insights from Missing Departure Airport Names**:<br>
# airbase (e.g. military base), resort, airports from less developed countries (e.g. South Sudan) or controversial countries (e.g. North Korea, Russia), unknown airports, too small of scale (e.g., airstrips), potential misspellings

# %%
# manually clean destination airports
df[df["Destination_airport"].notna() & (df["Destination_airport"] != "-") & df["Destination_airport_IATA"].isna() & df["Destination_airport_ICAO"].isna()][['Destination_airport', 'Matched_Airport_Name']].Destination_airport.value_counts().reset_index()['Destination_airport']
# Out:
# 0                                    Zhengzhou Air Base
# 1                             Nairobi (unknown airport)
# 2                                         Yida Airstrip
# 3                                        Tanay Airfield
# 4                                            Old Fangak
# 5                                  CÃ³rdoba Airport, CD
# 6                                            Inuvik, NT
# 7                                                  Oslo
# 8                               Filitheyo Seaplane Base
# 9                                   Washington, DC (DCA
# 10                    Aeropuerto Internacional de Salta
# 11                                                 SABE
# 12                                   Darwin Airport, NT
# 13                                                  AQP
# 14                              Fox Harbour Airport, NS
# 15                                 Rutherford Ranch, TX
# 16                                          Jacobkondre
# 17        Guayaquil-Simon Bolivar International Airport
# 18                             Moskva (unknown airport)
# 19                            Donlin Creek Airstrip, AK
# 20                                               Sangar
# 21                          Decatur-Bishop Airfield, TX
# 22                                                 MSLP
# 23                                  Sault Ste Marie, MI
# 24                                Birnin Kebbi Airstrip
# 25                      Weston-on-the-Green RAF Station
# 26                                           Las Palmas
# 27                                   Raleigh-Durham, NC
# 28                                      Tervel Airstrip
# 29                     Terra Nova Bay-Zucchelli Station
# 30                           Saint-Esprit Aerodrome, QC
# 31                                       Fort Myers, FL
# 32                          Uvalde-Ox Ranch Airport ,TX
# 33                                    Laytamak Airstrip
# 34                                  Tash Kumyr Airstrip
# 35                                Ridgeland Airport, SC
# 36                                      Los Angeles, CA
# 37                                       Kegen Airstrip
# 38                                    Angguruk Airstrip
# 39                                        Yuai Airstrip
# 40                                    Svalenik Airstrip
# 41                                     Taechon Air Base
# 42                                       Fort Worth, TX
# 43                   Chance Bay, Whitsunday Island, QLD
# 44                                Cookstown Airport, ON
# 45                                                  PEE
# 46                                                  FDO
# 47                                      Pogapa Airstrip
# 48                                     Guri'el Airstrip
# 49                              Maple Creek Airport, SK
# 50                                     Lusenge Airfield
# 51                Clayton County Airport-Tara Field, GA
# 52                                  Rackla Airstrip, YT
# 53                              Abu adh Dhuhur Air Base
# 54                                       Shatyrkul Mine
# 55                                      Mocuba Airstrip
# 56                                                 Kano
# 57                                 Barneo Camp Icestrip
# 58                                        Azov Airfield
# 59                                     Mandeng Airstrip
# 60                                        Agok Airstrip
# 61                                      Dompta Airstrip
# 62                                  Dry Bay Airport, AK
# 63                                      Rubkona Airport
# 64                                     Bardale Airstrip
# 65                             Bolton Lake Airstrip, MB
# 66                                     Maurice Lake, SK
# 67                                                 URRR
# 68                                 Fentress Airpark, TX
# 69                                  Manning Airport, AB
# 70                                     Lodi Airport, CA
# 71                                     Musiara Airstrip
# 72                                      Namoya Airstrip
# 73                    Franklin-Macon County Airport, NC
# 74                                        Doro Airstrip
# 75                                           Denver, CO
# 76                                    Sasereme Airstrip
# 77                        Azraq-Muwaffaq Salti Air Base
# 78                          Yalowega Lake Ice Strip, SK
# 79                            Perris Valley Airport, CA
# 80                                    Balashov Airfield
# 81                                 Gardiner Airport, NY
# 82                Kuredu Island Resort, Lhaviyani Atoll
# 83                                       Aksuat Airport
# 84                                                  LGW
# 85                                         Aru Airstrip
# 86                                           Barrow, AK
# 87                                     Lankien Airstrip
# 88                 Rio de Janeiro (unknown airport), RJ
# 89                                          Cairns, QLD
# 90                                         San Juan, PR
# 91                              Santiago de Chile - SCL
# 92                                    Maconacon Airport
# 93                                       Layfayette, LA
# 94                                            Tokyo-NRT
# 95                                        Boma Airstrip
# 96                               Deschambeault Lake, SK
# 97                                            Tony Camp
# 98                                  Lawa-Antino Airport
# 99             Kayenta-Peabody Bedard Field Airport, AZ
# 100                                    Teresita Airport
# 101                           Selway Lodge Airstrip, ID
# 102                                   Walikale Airstrip
# 103                             Berbegamau Airstrip, QC
# 104                                 Paderborn-Lippstadt
# 105                                 Nixon Fork Mine, AK
# 106                      Columbus (unknown airport), OH
# 107                               Sandy Bay Airport, SK
# 108                                      Zwedru Airport
# 109                                       Amisi Airport
# 110                                              Tersky
# 111                                     Haydom Airstrip
# 112                                           Kozlovets
# 113                                                SARI
# 114                                             Kamonya
# 115                                     Mozdok Air Base
# 116                                      Exeter Airport
# 117                                      Ulang airstrip
# 118                                       Sredny Island
# 119                   London Stansted Airport (STN/EGS)
# 120                                     Lakhta Air Base
# 121                                      Kavak Airstrip
# 122                                              Shamsi
# 123                 Burnsville-Mountain Air Airport, NC
# 124                                            PapelÃ³n
# 125                                    Wobagen Airstrip
# 126                          Kinshasa (unknown airport)
# 127                                        Dhaalu Atoll
# 128    Phinda Aerodrome. (Game Lodge near Richards Bay)
# 129                                       Ayod Airstrip
# 130              Daytona Beach-Spruce Creek Airport, FL
# 131                              KleinÂs Camp Airstrip
# 132                                   Larandia Air Base
# 133                                  Ceelbarde Airstrip
# 134                                 Badiraguato Airport
# 135                     Cottage Grove State Airport, OR
# 136                                       Borki Airport
# 137                       San Angelo-Ducote Airpark, TX
# 138                                       Eden Lake, BC
# 139                                                USDM
# 140                                                LTFG
# 141                                 Aksunkar (Kostanay)
# 142                                   Plesetsk Air Base
# 143                        Katchungu-Tchambogo Airstrip
# 144                                      Kasese Airport
# 145                               Ellington Airport, CT
# 146                                     South Perth, WA
# 147                          Jebel-Boma County Airstrip
# Name: Destination_airport, dtype: object

# %%
## manually mapped
iata_icao_mapping = {
    "SABE": ("AEP", "SABE"), "Sebastian Municipal Airport, FL": (None, None), "Tanay Airfield": (None, "XNET"),
    "Pieri Airstrip": (None, "SS-0007"), "Inuvik, NT": ("YEV", "CYEV"), "Decatur-Bishop Airfield, TX": (None, None),
    "Abuja": ("ABV", "DNAA"), "Ronald Reagan, DC (DCA": ("DCA", "KDCA"), "Ankara (unknown airport)": (None, None),
    "Quito": ("UIO", "SEQM"), "DELTA JUNCTION , AK (D66": ("DJN", None), "Estancia Las Cruces, ER": ("LRU", "KLRU"),
    "Moncton": ("YQM", "CYQM"), "Dili": (None, None), "LBGO": ("GOZ", "LBGO"), "Columbus, OH ( CMH)": ("CMH", "KCMH"),
    "AEP": ("AEP", "SABE"), "Piajo Airstrip": ("POS", "TTPP"), "Perryville Municipal Airport, MO": (None, "KPCD"),
    "Manning Airport, AB": (None, None), "Fentress Airpark, TX": (None, None), "Tayoltita Airstrip": (None, None),
    "Sterlitamark Airfield": (None, None), "Cookstown Airport, ON": (None, None), "Tash Kumyr Airstrip": (None, None),
    "Hamburg": ("HAM", "EDDH"), "Djolu Airport": (None, None), "South Pole-Amundsen-Scott Station": (None, "NZSP"),
    "SAEZ": ("EZE", "SAEZ"), "Rudyerd Bay, AK": (None, None), "Tianjin International Airport": ("TSN", "ZBTJ"),
    "Saint-Esprit Aerodrome, QC": (None, None), "Kidron-Stoltzfus Airfield, OH": (None, "OH22"),
    "Gods Lake Narrows, Manitoba": ("YGO", "CYGO"), "Hamilton-Ravalli County Airport, MT": (None, None),
    "Kaskattama Airstrip, MB": (None, None), "COMO Maalifushi Resort": (None, None), "Taechon Air Base": (None, None),
    "Lodi Airport, CA": ("1O3", None), "Kichwa Tembo Airstrip": ("KTJ", None), "Nairobi (unknown airport)": (None, None),
    "Lily Beach Resort, Huvahendhoo, Alif Dhaal Atoll": (None, None), "Ajongthok Airstrip": (None, None),
    "Kattleberg Airport": (None, None), "Azov Airfield": (None, "RUAZ"), "Caracas (unknown airport)": (None, None),
    "Jeddah": ("JED", "OEJN"), "Tersky": ("TYS", "KTYS"), "Miyazaki Airport": ("KMI", "RJFM"),
    "Clayton County Airport-Tara Field, GA": (None, "KHMP"), "Tharjath Airstrip": (None, None),
    "Sharara Airstrip": ("OAS", "OASA"), "Kuajok Airstrip": (None, None), "Gardiner Airport, NY": ("5NY5", "5NY5"),
    "Rio de Janeiro/Galeão-Antonio Carlos Jobim International Airport, RJ (GIG/SBG": ("GIG", "SBGL"),
    "Kuweires Air Base": (None, None), "Zhetygen Air Base": (None, None), "Dolow Airport": (None, None),
    "Rangali Island": (None, None), "Perris Valley Airport, CA": (None, None),
    "Five Point-Agro-West Airport, CA": ("5CA7", None), "Svalenik Airstrip": (None, None),
    "Mara Ngerende Airstrip": (None, None), "Weston-on-the-Green RAF Station": (None, None),
    "Tervel Airstrip": (None, None), "Saint Louis (unknown airport), MO": (None, None),
    "Sturt Island Airstrip": (None, "AYST"), "Larandia Air Base": (None, None), "Port de Pollença": (None, "LEPO"),
    "Obuasi Airstrip": (None, None), "Marial Bal Airstrip": (None, None), "Creswell-Hobby Field Airport, OR": (None, "K77S"),
    "Borki Airport": (None, None), "Sauce Viejo": ("SFN", "SAAV"), "USDA": ("SBT", "USDA"),
    "Juba International Airport": ("JUB", "HJJJ"), "Kajjansi Airfield ?": ("KJJ", "HUKJ"), "Juba": ("JUB", "HJJJ"),
    "Boston Logan International Airport": ("BOS", "KBOS"), "YRAY": (None, None), "Mayout airstrip": (None, None),
    "Mount Lymburner": (None, None), "Ust-Kara Airstrip": (None, None), "Ayers Rock, NT": ("AYQ", "YAYE"),
    "Kilimanjaro": ("JRO", "HTKJ"), "Kanantik Airstrip": ("SVK", "MZKT"), "Casablanca (unknown airport)": (None, None),
    "Bishkek District Airport": (None, None), "Elk Island Airport, MB": (None, None), "Walikale Airstrip": (None, None),
    "Šentvid pri Sticni Airfield": (None, None), "Medellín (unknown airport)": (None, None), "Kozlovets": ("SVX", "USSS"),
    "Jiech": (None, None), "Novolazarevskaya Station": ("QAO", "AT17"), "Medan": ("KNO", "WIMM"),
    "Dolinsk-Sokol Air Base": (None, "XHSO"), "Ciudad del Este - AGT": ("AGT", "SGES"),
    "Bagay-Baranovka Airport": (None, None), "Bozoy": (None, None), "Ganes Creek, AK": ("GEK", None),
    "McGrath, AK": ("MCG", "PAMC"), "Ellington Airport, CT": (None, None), "Purari": (None, None),
    "Kalamazoo-Battle Creek International Airport, MI": ("AZO", "KAZO"), "GPOC Unity Airstrip": (None, None),
    "Rottnest Island, WA": ("RTS", "YRTI")
}

def map_airport_codes(airport_name):
    """Returns the IATA and ICAO codes for a given airport name."""
    return iata_icao_mapping.get(airport_name, (None, None))

# Apply mapping function to dataframe
df_airports["IATA"], df_airports["ICAO"] = zip(*df_airports["original"].apply(map_airport_codes))

# Display the final mapped dataset
import ace_tools as tools
tools.display_dataframe_to_user(name="Mapped IATA and ICAO Codes", dataframe=df_airports)

# %%
airports_df = pd.read_csv("../data/airports.csv")

# %%
# from rapidfuzz import process, fuzz  # faster alternative to fuzzywuzzy

# airports_df = pd.read_csv("../data/airports.csv")

# # find best fuzzy match using Levenshtein ratio 
# # (https://stackoverflow.com/questions/64711569/how-to-optimize-an-algorithm-to-find-similar-strings-with-fuzzywuzzy-faster)
# def find_best_match(airport_name, reference_df, column_to_match):
#     """Finds the best fuzzy match for an airport name using Levenshtein ratio."""
#     best_match = process.extractOne(airport_name, reference_df[column_to_match], scorer=fuzz.ratio, score_cutoff=85)
#     return best_match[0] if best_match else None

# # filter only rows where Departure_airport is not null and not "-"
# # and either Departure_airport_IATA or Departure_airport_ICAO is null
# mask = (
#     df["Departure_airport"].notna() &
#     (df["Departure_airport"] != "-") &
#     (df["Departure_airport_IATA"].isna()) & (df["Departure_airport_ICAO"].isna())
# )

# # Apply fuzzy matching only to the filtered rows
# df.loc[mask, "Matched_Airport_Name"] = df.loc[mask, "Departure_airport"].apply(
#     lambda x: find_best_match(x, airports_df, "Name") if pd.notna(x) else None
# )

# # Merge with the airports dataset to fill missing IATA/ICAO based on name matches
# df_merged = df.merge(airports_df[["Name", "IATA", "ICAO"]], 
#                      left_on="Matched_Airport_Name", 
#                      right_on="Name", 
#                      how="left")

# # Fill missing values for IATA and ICAO
# df_merged["Departure_airport_IATA"].fillna(df_merged["IATA"], inplace=True)
# df_merged["Departure_airport_ICAO"].fillna(df_merged["ICAO"], inplace=True)

# # Drop unnecessary columns
# df_merged.drop(columns=["Matched_Airport_Name", "Name", "IATA", "ICAO"], inplace=True)

# %%
# from fuzzywuzzy import process

# airports_df = pd.read_csv("../data/airports.csv")

# # clean missing airport IATA & ICAO codes by attempting a name-based match
# def find_best_match(airport_name, reference_df, column_to_match):
#     """Find the best fuzzy match for an airport name in the reference dataset."""
#     best_match = process.extractOne(airport_name, reference_df[column_to_match], score_cutoff=85)
#     return best_match[0] if best_match else None

# df.loc[df["Departure_airport_IATA"].isna(), "Matched_Airport_Name"] = df["Departure_airport"].apply(
#     lambda x: find_best_match(x, airports_df, "Name") if pd.notna(x) else None
# )
# df.loc[df["Destination_airport_IATA"].isna(), "Matched_Airport_Name"] = df["Destination_airport"].apply(
#     lambda x: find_best_match(x, airports_df, "Name") if pd.notna(x) else None
# )

# # merge with the airports dataset to fill missing IATA/ICAO based on name matches
# df_merged = df.merge(airports_df[["Name", "IATA", "ICAO"]], 
#               left_on="Matched_Airport_Name", right_on="Name", how="left")

# df_merged["Departure_airport_IATA"].fillna(df_merged["IATA"], inplace=True)
# df_merged["Departure_airport_ICAO"].fillna(df_merged["ICAO"], inplace=True)

# df_merged["Destination_airport_IATA"].fillna(df_merged["IATA"], inplace=True)
# df_merged["Destination_airport_ICAO"].fillna(df_merged["ICAO"], inplace=True)

# df_merged.drop(columns=["Matched_Airport_Name", "Name", "IATA", "ICAO"], inplace=True)
# Out:
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# ...
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '-']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[54], line 14
#       9     return best_match[0] if best_match else None
#      11 df.loc[df["Departure_airport_IATA"].isna(), "Matched_Airport_Name"] = df["Departure_airport"].apply(
#      12     lambda x: find_best_match(x, airports_df, "Name") if pd.notna(x) else None
#      13 )
# ---> 14 df.loc[df["Destination_airport_IATA"].isna(), "Matched_Airport_Name"] = df["Destination_airport"].apply(
#      15     lambda x: find_best_match(x, airports_df, "Name") if pd.notna(x) else None
#      16 )
#      18 # merge with the airports dataset to fill missing IATA/ICAO based on name matches
#      19 df_merged = df.merge(airports_df[["Name", "IATA", "ICAO"]],
#      20               left_on="Matched_Airport_Name", right_on="Name", how="left")
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[54], line 15, in <lambda>(x)
#       9     return best_match[0] if best_match else None
#      11 df.loc[df["Departure_airport_IATA"].isna(), "Matched_Airport_Name"] = df["Departure_airport"].apply(
#      12     lambda x: find_best_match(x, airports_df, "Name") if pd.notna(x) else None
#      13 )
#      14 df.loc[df["Destination_airport_IATA"].isna(), "Matched_Airport_Name"] = df["Destination_airport"].apply(
# ---> 15     lambda x: find_best_match(x, airports_df, "Name") if pd.notna(x) else None
#      16 )
#      18 # merge with the airports dataset to fill missing IATA/ICAO based on name matches
#      19 df_merged = df.merge(airports_df[["Name", "IATA", "ICAO"]],
#      20               left_on="Matched_Airport_Name", right_on="Name", how="left")
#
# Cell In[54], line 8, in find_best_match(airport_name, reference_df, column_to_match)
#       6 def find_best_match(airport_name, reference_df, column_to_match):
#       7     """Find the best fuzzy match for an airport name in the reference dataset."""
# ----> 8     best_match = process.extractOne(airport_name, reference_df[column_to_match], score_cutoff=85)
#       9     return best_match[0] if best_match else None
#
# File /opt/anaconda3/lib/python3.12/site-packages/fuzzywuzzy/process.py:220, in extractOne(query, choices, processor, scorer, score_cutoff)
#     218 best_list = extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#     219 try:
# --> 220     return max(best_list, key=lambda i: i[1])
#     221 except ValueError:
#     222     return None
#
# File /opt/anaconda3/lib/python3.12/site-packages/fuzzywuzzy/process.py:110, in extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#     108 for key, choice in choices.items():
#     109     processed = pre_processor(processor(choice))
# --> 110     score = scorer(processed_query, processed)
#     111     if score >= score_cutoff:
#     112         yield (choice, score, key)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fuzzywuzzy/fuzz.py:289, in WRatio(s1, s2, force_ascii, full_process)
#     287 if try_partial:
#     288     partial = partial_ratio(p1, p2) * partial_scale
# --> 289     ptsor = partial_token_sort_ratio(p1, p2, full_process=False) \
#     290         * unbase_scale * partial_scale
#     291     ptser = partial_token_set_ratio(p1, p2, full_process=False) \
#     292         * unbase_scale * partial_scale
#     294     return utils.intr(max(base, partial, ptsor, ptser))
#
# File /opt/anaconda3/lib/python3.12/site-packages/fuzzywuzzy/fuzz.py:112, in partial_token_sort_ratio(s1, s2, force_ascii, full_process)
#     108 def partial_token_sort_ratio(s1, s2, force_ascii=True, full_process=True):
#     109     """Return the ratio of the most similar substring as a number between
#     110     0 and 100 but sorting the token before comparing.
#     111     """
# --> 112     return _token_sort(s1, s2, partial=True, force_ascii=force_ascii, full_process=full_process)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fuzzywuzzy/utils.py:38, in check_for_none.<locals>.decorator(*args, **kwargs)
#      36 if args[0] is None or args[1] is None:
#      37     return 0
# ---> 38 return func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fuzzywuzzy/fuzz.py:96, in _token_sort(s1, s2, partial, force_ascii, full_process)
#      93 sorted2 = _process_and_sort(s2, force_ascii, full_process=full_process)
#      95 if partial:
# ---> 96     return partial_ratio(sorted1, sorted2)
#      97 else:
#      98     return ratio(sorted1, sorted2)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fuzzywuzzy/utils.py:38, in check_for_none.<locals>.decorator(*args, **kwargs)
#      36 if args[0] is None or args[1] is None:
#      37     return 0
# ---> 38 return func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fuzzywuzzy/utils.py:29, in check_for_equivalence.<locals>.decorator(*args, **kwargs)
#      27 if args[0] == args[1]:
#      28     return 100
# ---> 29 return func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fuzzywuzzy/utils.py:47, in check_empty_string.<locals>.decorator(*args, **kwargs)
#      45 if len(args[0]) == 0 or len(args[1]) == 0:
#      46     return 0
# ---> 47 return func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/fuzzywuzzy/fuzz.py:62, in partial_ratio(s1, s2)
#      59 long_substr = longer[long_start:long_end]
#      61 m2 = SequenceMatcher(None, shorter, long_substr)
# ---> 62 r = m2.ratio()
#      63 if r > .995:
#      64     return 100
#
# File /opt/anaconda3/lib/python3.12/difflib.py:619, in SequenceMatcher.ratio(self)
#     597 def ratio(self):
#     598     """Return a measure of the sequences' similarity (float in [0,1]).
#     599
#     600     Where T is the total number of elements in both sequences, and
#    (...)
#     616     1.0
#     617     """
# --> 619     matches = sum(triple[-1] for triple in self.get_matching_blocks())
#     620     return _calculate_ratio(matches, len(self.a) + len(self.b))
#
# File /opt/anaconda3/lib/python3.12/difflib.py:452, in SequenceMatcher.get_matching_blocks(self)
#     450 queue = [(0, la, 0, lb)]
#     451 matching_blocks = []
# --> 452 while queue:
#     453     alo, ahi, blo, bhi = queue.pop()
#     454     i, j, k = x = self.find_longest_match(alo, ahi, blo, bhi)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Data Visualization
# Produce 3 or more plots that help describe your data.  Choose appropriate visualizations
